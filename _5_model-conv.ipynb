# %%
from packages import *
import tensorflow as tf
from datetime import datetime, timedelta
import time
import pandas as pd
import tensorflow.keras.backend as K
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import *
from sklearn.metrics import classification_report, precision_recall_fscore_support, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import shuffle
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Model
# We will be building our models in this notebook.

# %% [markdown]
# Some configuration required for tensorflow.

# %%
tf.config.gpu.set_per_process_memory_growth(True)
tf.config.gpu.set_per_process_memory_fraction(.3)
tf.keras.backend.set_image_data_format('channels_last')

# %% [markdown]
# ## Dataset

# %%
glove_dim = 50
max_length = 300
chunk_count = 100
random_seed = np.random.randint(0, 1000000000)
print('using random_seed: {}'.format(random_seed))
splits = ['train', 'val', 'test'] #60:20:20
# Out:
# using random_seed: 456893372

# %%
tf_text_filenames = [os.path.join(DATASET_DIR, 'preprocessed', 'tfrecord', 'xext',  #xext temporarily
                                  'review-text-{:02d}.tf'.format(i)) for i in range(chunk_count)]
tf_ix_filenames = [os.path.join(DATASET_DIR, 'preprocessed', 'tfrecord', 'ix', 
                                  'review-ix-{:02d}.tf'.format(i)) for i in range(chunk_count)]
all_stars = (load_data({'review': ['stars']})['review']['stars'] - 1).astype(np.int32)# this is so that stars are 0-indexed
N = {}
stars_chunked = all_stars.reshape((chunk_count, 6685900//chunk_count))

class_weights = compute_class_weight('balanced', [0, 1, 2, 3, 4], all_stars)
class_weights = {'five': class_weights, 'ternary': np.array([class_weights[0], class_weights[1:4].sum() , class_weights[4]])}

tf_text, tf_ix, stars= {}, {}, {}

tf_text['train'], tf_text_filenames_val_test, tf_ix['train'], tf_ix_filenames_val_test, stars['train'], stars_val_test \
= train_test_split(tf_text_filenames, tf_ix_filenames, stars_chunked, random_state=random_seed, test_size = .4)

tf_text['val'], tf_text['test'], tf_ix['val'], tf_ix['test'], stars['val'], stars['test'] \
= train_test_split(tf_text_filenames_val_test, tf_ix_filenames_val_test, stars_val_test, random_state=random_seed, test_size = .5)

for split in splits:
    stars[split] = stars[split].reshape(np.product(stars[split].shape))
    N[split] = len(stars[split])

print('({}:{}:{})'.format(len(tf_text['train']), len(tf_text['val']), len(tf_text['test'])))

glove_lookup = load_pickle(os.path.join(GLOVE_DIR, 'glove-{}D-byte-float32.pkl'.format(glove_dim)))
keys_to_ix = load_pickle(os.path.join(GLOVE_DIR, 'glove-byte-keys_to_ix.pkl'))
ix_to_key = {value: key for key, value in keys_to_ix.items()}

unk_vector = np.mean(np.array(list(glove_lookup.values())), axis=0)
null_vector = np.zeros(glove_dim)
glove_lookup[UNK_KEY.encode('ascii')] = unk_vector #if using byte glove dict
glove_lookup[NULL_KEY.encode('ascii')] = null_vector

oops = 0
glove_lookup_array = []
for i in range(len(ix_to_key)):
    if ix_to_key[i] not in glove_lookup:
        oops+=1
    glove_lookup_array.append(glove_lookup.get(ix_to_key[i], null_vector))
glove_lookup_array = np.array(glove_lookup_array, dtype=np.float32)
print('oops {} times.'.format(oops))

@tf.function
def get_review_length(review):
    return tf.cast(tf.reduce_sum(tf.cast(tf.not_equal(review, 0), tf.int8)), tf.int32)

@tf.function
def _parse_function(proto, to_ix):
    # define your tfrecord again. Remember that you saved your image as a string.
    keys_to_features = {'review': tf.io.FixedLenFeature([300,], tf.int64) if to_ix else tf.io.FixedLenFeature([300,], tf.string),}
    
    # Load one example
    parsed_features = tf.io.parse_single_example(proto, keys_to_features)
    
    return parsed_features 

embedding = tf.constant(glove_lookup_array)
@tf.function
def embed(tensor):
    return tf.gather(embedding, tensor)

@tf.function
def add_channel(tensor):
    return tf.expand_dims(tensor, -1)

# 11 GB in memory
# X = []
# x = tf.data.TFRecordDataset(tf_text['train'])
# for y in x :
#     X.append(y)

def make_dataset(batch_size, to_embed=True, to_ix=True, to_str=False, channelize=True, to_ternary_task=False, features= {}): 
    '''
    Note: once created dataset remains the same from iteration to iteration. 
    In Keras.fit, once given steps_per_epoch the data for epochs are not the same.
    Validation data is the same.
    If cell is rerun, then the same order of data will be fed.
    '''
    if to_ternary_task:
        star_mapping = tf.constant([0, 1, 1, 1, 2], dtype=tf.int32)
    def _prepare_star(star):
        if to_ternary_task: return {'stars': tf.gather(star_mapping, star)}
        return {'stars': star}
    def _parse_transform(x):
        parsed = _parse_function(x, to_ix or to_embed)['review']
        out = {key: f(x) for key, f in features.items()}
        if to_ix:
            out['review-ix'] = tf.cast(parsed, tf.int32)
        if to_embed:
            if channelize:
                out['review-embed'] = add_channel(embed(parsed))
            else:
                out['review-embed'] = embed(parsed)
        if to_str:
            pass  
        return out   
    
    shuffle_buffer_size = batch_size * 100
    prefetch_buffer_size = 4
    if to_embed or to_ix: 
        files = tf_ix
    else:
        files = tf_text
    dataset = {}
    num_batches = {}
    for split in splits:
        dataset[split] = tf.data.TFRecordDataset(files[split])
        stars_dataset = tf.data.Dataset.from_tensor_slices(stars[split])
        dataset[split] = tf.data.Dataset.zip((dataset[split], stars_dataset))
        dataset[split] = dataset[split].shuffle(shuffle_buffer_size)
        dataset[split] = dataset[split].repeat()
        dataset[split] = dataset[split].map(lambda x, y: (_parse_transform(x), _prepare_star(y)), num_parallel_calls=12)
        dataset[split] = dataset[split].batch(batch_size)
        dataset[split] = dataset[split].prefetch(prefetch_buffer_size)
        num_batches[split] = N[split] // batch_size
    print('num_batches: {}, batch_size: {}, shuffle_buffer_size: {}, prefetch_buffer_size: {}'.format(num_batches, batch_size, 
                                                                                 shuffle_buffer_size, prefetch_buffer_size))
    return dataset, num_batches
# Out:
# (60:20:20)
# oops 1 times.

# %%
# %%time
# for i, (x, y) in enumerate(dataset['train']):
#     if i == 500:
#         break
# for i, (x, y) in enumerate(dataset['train']):
#     if i == 500:
#         break
# # Wall time: 30.1 --> 14.2 --> 4.3 s wow (64 batchsize, glovedim = 300)

# %%
# for x_init, y_init in dataset['train']:break

# %% [markdown]
# # Models

# %% [markdown]
# ### BabyBlueberry
# Convolutional Model with GLoVe embeddings.

# %%
@rename('all_acc')
def all_class_accuracy(y_true, y_pred):
    return tf.keras.metrics.sparse_categorical_accuracy(y_true, y_pred) 

def one_class_recall(label):
    @rename('{}_recalll'.format(label))
    def single_class_recall(y_true, y_pred): # (64, 1), (64, 5) should return (64,)
        truth = K.flatten(K.cast(y_true, 'int32'))
        preds = K.cast(K.argmax(y_pred, axis=-1), 'int32')
        recall_mask = K.cast(K.equal(truth, label), 'int32')        
        recall = K.cast(K.equal(preds, truth), 'int32') * recall_mask
        recall = K.cast(K.sum(recall) / K.maximum(K.sum(recall_mask), 1), 'float32')
        return  K.ones(batch_size, dtype='float32') * recall
    return single_class_recall

def one_class_precision(label):
    @rename('{}_precision'.format(label))
    def single_class_precision(y_true, y_pred): # (64, 1), (64, 5) should return (64,)
        truth = K.flatten(K.cast(y_true, 'int32'))
        preds = K.cast(K.argmax(y_pred, axis=-1), 'int32')
        precision_mask = K.cast(K.equal(preds, label), 'int32')          
        precision = K.cast(K.equal(preds, truth), 'int32') * precision_mask
        precision = K.cast(K.sum(precision) / K.maximum(K.sum(precision_mask), 1), 'float32')
        return  K.ones(batch_size, dtype='float32') * precision
    return single_class_precision

# %%
star_metrics = [all_class_accuracy]
star_metrics += [one_class_recall(i) for i in range(5)] + [one_class_precision(i) for i in range(5)]

# %%
def get_kernel_spec(filters, height, width):
    return {'filters':filters, 'height': height, 'width': width}

# %%
class BabyBerry:
    
    def build(dropout_rate, kernels, out_units, input_shape=(max_length, glove_dim, 1)):
        ix_input = Input(shape= (max_length,), name='review-ix')
        glove_input = Input(shape=input_shape, name='review-embed')
        
        embedding = Embedding(input_dim=len(glove_lookup_array), output_dim=glove_dim, 
                              input_length=max_length, name='trained_embed')(ix_input)
        
        channel_embedding = Reshape(target_shape=(max_length, glove_dim, 1), name='reshape_embed')(embedding)
                
        combined_embedding = Concatenate(name='concat_embed')([channel_embedding, glove_input])
        branches = []
        names = {}
        for kernel in kernels:
            if (kernel['height'], kernel['width']) in names:
                names[(kernel['height'], kernel['width'])] = i = names[(kernel['height'], kernel['width'])] + 1
            else:
                names[(kernel['height'], kernel['width'])] = i = 1
            branch = Conv2D(kernel['filters'], (kernel['height'], kernel['width']), activation='relu', 
                            name='conv_{}_{}_{}'.format(kernel['height'], kernel['width'], i), 
                            padding='valid')(combined_embedding)
            branch = GlobalMaxPool2D(name='pool_{}_{}_{}'.format(kernel['height'], kernel['width'], i))(branch)
            branches.append(branch)
        
        
        x = Concatenate(name='concat_conv')(branches)
        x = Dropout(rate=dropout_rate, name='dropout_1')(x)
        x = Dense(100, activation='relu', name='dense_1')(x)
        out = Dense(out_units, activation='softmax', name='stars')(x)
        
        return tf.keras.models.Model(inputs={'review-embed':glove_input, 'review-ix': ix_input}, 
                                     outputs={'stars': out}, name='BabyBerry')
        
    @tf.function
    def loss_fn(truth, logits):
        loss = tf.keras.losses.sparse_categorical_crossentropy(truth, logits)
        return loss

# %%
batch_size = 128
dataset, num_batches = make_dataset(batch_size=batch_size, to_embed=True, to_ix=True, channelize=True, to_ternary_task=False)
# Out:
# num_batches: {'train': 31340, 'val': 10446, 'test': 10446}, batch_size: 128, shuffle_buffer_size: 12800, prefetch_buffer_size: 4

# %%
kernels = [get_kernel_spec(filters=100, height=h, width=glove_dim) for h in [2, 3, 4, 5, 10]]
baby = BabyBerry.build(kernels=kernels, dropout_rate=.1, out_units=5)
adam = tf.keras.optimizers.Adam()
baby.compile(optimizer=adam, metrics={'stars': star_metrics} ,loss={'stars': BabyBerry.loss_fn})

# %%
plot_model(baby, show_shapes=True, rankdir='LR', to_file='images/conv_baby_berry_model.png')

# %%
log_dir = os.path.join(SRC_DIR, 'logs', '{}-CONV-BabyBerry'.format(datetime.fromtimestamp(time.time()).strftime('%d-%m_%H-%M-%S')))
tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir, write_graph=False, update_freq='batch')

# %%
_=baby.fit(dataset['train'], steps_per_epoch=300, epochs=100, 
                             validation_data= dataset['val'], validation_steps=20,
                             callbacks=[tb], class_weight=class_weights['five'], verbose=1)
# Out:
# Epoch 1/100
#   1/300 [..............................] - ETA: 9:40 - loss: 1.6532 - all_acc: 0.1250 - 0_recalll: 0.0667 - 1_recalll: 1.0000 - 2_recalll: 0.0000e+00 - 3_recalll: 0.0000e+00 - 4_recalll: 0.0000e+00 - 0_precision: 0.1429 - 1_precision: 0.1240 - 2_precision: 0.0000e+00 - 3_precision: 0.0000e+00 - 4_precision: 0.0000e+00
# WARNING: Logging before flag parsing goes to stderr.
# W0608 12:11:55.433346 140017833109312 callbacks.py:236] Method (on_train_batch_end) is slow compared to the batch update (0.139539). Check your callbacks.
# 300/300 [==============================] - 52s 173ms/step - loss: 0.9599 - all_acc: 0.5957 - 0_recalll: 0.7065 - 1_recalll: 0.1022 - 2_recalll: 0.2481 - 3_recalll: 0.3487 - 4_recalll: 0.8548 - 0_precision: 0.6166 - 1_precision: 0.2028 - 2_precision: 0.3333 - 3_precision: 0.4342 - 4_precision: 0.6927 - val_loss: 0.8353 - val_all_acc: 0.6457 - val_0_recalll: 0.5950 - val_1_recalll: 0.2681 - val_2_recalll: 0.4643 - val_3_recalll: 0.5660 - val_4_recalll: 0.8250 - val_0_precision: 0.8458 - val_1_precision: 0.3465 - val_2_precision: 0.4030 - val_3_precision: 0.5124 - val_4_precision: 0.7877
# Epoch 2/100
# 300/300 [==============================] - 52s 175ms/step - loss: 0.8024 - all_acc: 0.6569 - 0_recalll: 0.8310 - 1_recalll: 0.2565 - 2_recalll: 0.3921 - 3_recalll: 0.4377 - 4_recalll: 0.8552 - 0_precision: 0.7287 - 1_precision: 0.4296 - 2_precision: 0.4630 - 3_precision: 0.5082 - 4_precision: 0.7672 - val_loss: 0.7705 - val_all_acc: 0.6641 - val_0_recalll: 0.8796 - val_1_recalll: 0.4446 - val_2_recalll: 0.2713 - val_3_recalll: 0.6545 - val_4_recalll: 0.7386 - val_0_precision: 0.6940 - val_1_precision: 0.4621 - val_2_precision: 0.5045 - val_3_precision: 0.4954 - val_4_precision: 0.8565
# Epoch 3/100
# 300/300 [==============================] - 53s 175ms/step - loss: 0.7554 - all_acc: 0.6798 - 0_recalll: 0.8535 - 1_recalll: 0.2949 - 2_recalll: 0.3871 - 3_recalll: 0.4554 - 4_recalll: 0.8622 - 0_precision: 0.7412 - 1_precision: 0.4578 - 2_precision: 0.4767 - 3_precision: 0.5238 - 4_precision: 0.7863 - val_loss: 0.7547 - val_all_acc: 0.6734 - val_0_recalll: 0.8483 - val_1_recalll: 0.2285 - val_2_recalll: 0.3012 - val_3_recalll: 0.5232 - val_4_recalll: 0.8739 - val_0_precision: 0.7478 - val_1_precision: 0.4938 - val_2_precision: 0.5284 - val_3_precision: 0.5012 - val_4_precision: 0.7665
# Epoch 4/100
# 300/300 [==============================] - 53s 178ms/step - loss: 0.7276 - all_acc: 0.6951 - 0_recalll: 0.8735 - 1_recalll: 0.2951 - 2_recalll: 0.3991 - 3_recalll: 0.4496 - 4_recalll: 0.8750 - 0_precision: 0.7649 - 1_precision: 0.4508 - 2_precision: 0.4936 - 3_precision: 0.5311 - 4_precision: 0.7927 - val_loss: 0.7474 - val_all_acc: 0.6738 - val_0_recalll: 0.9254 - val_1_recalll: 0.3642 - val_2_recalll: 0.4018 - val_3_recalll: 0.3437 - val_4_recalll: 0.8879 - val_0_precision: 0.6752 - val_1_precision: 0.4813 - val_2_precision: 0.4560 - val_3_precision: 0.5795 - val_4_precision: 0.7615
# Epoch 5/100
# 300/300 [==============================] - 53s 178ms/step - loss: 0.7280 - all_acc: 0.6937 - 0_recalll: 0.8581 - 1_recalll: 0.3216 - 2_recalll: 0.4190 - 3_recalll: 0.4609 - 4_recalll: 0.8744 - 0_precision: 0.7556 - 1_precision: 0.4652 - 2_precision: 0.4884 - 3_precision: 0.5430 - 4_precision: 0.7953 - val_loss: 0.7255 - val_all_acc: 0.6875 - val_0_recalll: 0.8735 - val_1_recalll: 0.3161 - val_2_recalll: 0.4328 - val_3_recalll: 0.3884 - val_4_recalll: 0.9126 - val_0_precision: 0.7378 - val_1_precision: 0.4575 - val_2_precision: 0.4959 - val_3_precision: 0.5964 - val_4_precision: 0.7546
# Epoch 6/100
# 300/300 [==============================] - 54s 179ms/step - loss: 0.7443 - all_acc: 0.6817 - 0_recalll: 0.8267 - 1_recalll: 0.3711 - 2_recalll: 0.4200 - 3_recalll: 0.4847 - 4_recalll: 0.8656 - 0_precision: 0.7446 - 1_precision: 0.4877 - 2_precision: 0.5075 - 3_precision: 0.5552 - 4_precision: 0.7861 - val_loss: 0.7096 - val_all_acc: 0.6898 - val_0_recalll: 0.9162 - val_1_recalll: 0.2256 - val_2_recalll: 0.4889 - val_3_recalll: 0.4062 - val_4_recalll: 0.8980 - val_0_precision: 0.7172 - val_1_precision: 0.5013 - val_2_precision: 0.5084 - val_3_precision: 0.5824 - val_4_precision: 0.7616
# Epoch 7/100
# 300/300 [==============================] - 54s 179ms/step - loss: 0.7335 - all_acc: 0.6892 - 0_recalll: 0.8337 - 1_recalll: 0.3891 - 2_recalll: 0.4244 - 3_recalll: 0.4877 - 4_recalll: 0.8711 - 0_precision: 0.7609 - 1_precision: 0.4842 - 2_precision: 0.5039 - 3_precision: 0.5637 - 4_precision: 0.7901 - val_loss: 0.7111 - val_all_acc: 0.6918 - val_0_recalll: 0.8619 - val_1_recalll: 0.3541 - val_2_recalll: 0.3802 - val_3_recalll: 0.4875 - val_4_recalll: 0.8870 - val_0_precision: 0.7626 - val_1_precision: 0.4907 - val_2_precision: 0.5535 - val_3_precision: 0.5397 - val_4_precision: 0.7749
# Epoch 8/100
# 300/300 [==============================] - 53s 177ms/step - loss: 0.7214 - all_acc: 0.6947 - 0_recalll: 0.8516 - 1_recalll: 0.3248 - 2_recalll: 0.4712 - 3_recalll: 0.4919 - 4_recalll: 0.8660 - 0_precision: 0.7602 - 1_precision: 0.4745 - 2_precision: 0.5277 - 3_precision: 0.5655 - 4_precision: 0.7897 - val_loss: 0.6998 - val_all_acc: 0.6926 - val_0_recalll: 0.8764 - val_1_recalll: 0.3030 - val_2_recalll: 0.3838 - val_3_recalll: 0.5032 - val_4_recalll: 0.8835 - val_0_precision: 0.7224 - val_1_precision: 0.4106 - val_2_precision: 0.5203 - val_3_precision: 0.5811 - val_4_precision: 0.7896
# Epoch 9/100
# 300/300 [==============================] - 53s 178ms/step - loss: 0.7036 - all_acc: 0.6999 - 0_recalll: 0.8576 - 1_recalll: 0.3638 - 2_recalll: 0.4313 - 3_recalll: 0.4849 - 4_recalll: 0.8731 - 0_precision: 0.7672 - 1_precision: 0.4891 - 2_precision: 0.5240 - 3_precision: 0.5558 - 4_precision: 0.7957 - val_loss: 0.7056 - val_all_acc: 0.6895 - val_0_recalll: 0.8129 - val_1_recalll: 0.3822 - val_2_recalll: 0.5311 - val_3_recalll: 0.5554 - val_4_recalll: 0.8168 - val_0_precision: 0.8007 - val_1_precision: 0.4635 - val_2_precision: 0.4697 - val_3_precision: 0.5522 - val_4_precision: 0.8241
# Epoch 10/100
# 300/300 [==============================] - 53s 178ms/step - loss: 0.7019 - all_acc: 0.7060 - 0_recalll: 0.8680 - 1_recalll: 0.3636 - 2_recalll: 0.4381 - 3_recalll: 0.4884 - 4_recalll: 0.8771 - 0_precision: 0.7716 - 1_precision: 0.4843 - 2_precision: 0.5264 - 3_precision: 0.5613 - 4_precision: 0.8016 - val_loss: 0.7110 - val_all_acc: 0.6824 - val_0_recalll: 0.7924 - val_1_recalll: 0.3790 - val_2_recalll: 0.3772 - val_3_recalll: 0.5662 - val_4_recalll: 0.8486 - val_0_precision: 0.7839 - val_1_precision: 0.4434 - val_2_precision: 0.5270 - val_3_precision: 0.5265 - val_4_precision: 0.7941
# Epoch 11/100
# 300/300 [==============================] - 53s 177ms/step - loss: 0.6995 - all_acc: 0.7039 - 0_recalll: 0.8638 - 1_recalll: 0.3650 - 2_recalll: 0.4290 - 3_recalll: 0.5019 - 4_recalll: 0.8740 - 0_precision: 0.7658 - 1_precision: 0.4846 - 2_precision: 0.5252 - 3_precision: 0.5682 - 4_precision: 0.7993 - val_loss: 0.6903 - val_all_acc: 0.6949 - val_0_recalll: 0.9056 - val_1_recalll: 0.3012 - val_2_recalll: 0.3954 - val_3_recalll: 0.4878 - val_4_recalll: 0.8853 - val_0_precision: 0.7191 - val_1_precision: 0.4799 - val_2_precision: 0.5282 - val_3_precision: 0.5589 - val_4_precision: 0.7882
# Epoch 12/100
# 300/300 [==============================] - 53s 178ms/step - loss: 0.7066 - all_acc: 0.6985 - 0_recalll: 0.8487 - 1_recalll: 0.3647 - 2_recalll: 0.4571 - 3_recalll: 0.5021 - 4_recalll: 0.8717 - 0_precision: 0.7589 - 1_precision: 0.5014 - 2_precision: 0.5335 - 3_precision: 0.5654 - 4_precision: 0.7963 - val_loss: 0.6981 - val_all_acc: 0.6902 - val_0_recalll: 0.7754 - val_1_recalll: 0.5772 - val_2_recalll: 0.4280 - val_3_recalll: 0.4037 - val_4_recalll: 0.9013 - val_0_precision: 0.7953 - val_1_precision: 0.4181 - val_2_precision: 0.5358 - val_3_precision: 0.6142 - val_4_precision: 0.7687
# Epoch 13/100
# 300/300 [==============================] - 53s 178ms/step - loss: 0.7014 - all_acc: 0.7033 - 0_recalll: 0.8413 - 1_recalll: 0.4034 - 2_recalll: 0.4631 - 3_recalll: 0.4965 - 4_recalll: 0.8769 - 0_precision: 0.7610 - 1_precision: 0.5197 - 2_precision: 0.5379 - 3_precision: 0.5678 - 4_precision: 0.8012 - val_loss: 0.6914 - val_all_acc: 0.6977 - val_0_recalll: 0.9203 - val_1_recalll: 0.3667 - val_2_recalll: 0.4620 - val_3_recalll: 0.3712 - val_4_recalll: 0.9171 - val_0_precision: 0.7142 - val_1_precision: 0.5460 - val_2_precision: 0.5492 - val_3_precision: 0.6113 - val_4_precision: 0.7576
# Epoch 14/100
# 300/300 [==============================] - 70s 233ms/step - loss: 0.6994 - all_acc: 0.7046 - 0_recalll: 0.8535 - 1_recalll: 0.3881 - 2_recalll: 0.4590 - 3_recalll: 0.5034 - 4_recalll: 0.8762 - 0_precision: 0.7590 - 1_precision: 0.5105 - 2_precision: 0.5399 - 3_precision: 0.5799 - 4_precision: 0.8017 - val_loss: 0.6843 - val_all_acc: 0.6992 - val_0_recalll: 0.8183 - val_1_recalll: 0.4896 - val_2_recalll: 0.4775 - val_3_recalll: 0.4385 - val_4_recalll: 0.8920 - val_0_precision: 0.7683 - val_1_precision: 0.4492 - val_2_precision: 0.5291 - val_3_precision: 0.6057 - val_4_precision: 0.7843
# Epoch 15/100
# 189/300 [=================>............] - ETA: 24s - loss: 0.6921 - all_acc: 0.7059 - 0_recalll: 0.8454 - 1_recalll: 0.3674 - 2_recalll: 0.4654 - 3_recalll: 0.5036 - 4_recalll: 0.8814 - 0_precision: 0.7509 - 1_precision: 0.4829 - 2_precision: 0.5400 - 3_precision: 0.5805 - 4_precision: 0.8039

# %%
truth, predictions = [], []
for x, y in dataset['val'].take(200):
    pred = baby(x)
    truth.append(y['stars'].numpy())
    predictions.append(tf.argmax(pred['stars'], axis=-1).numpy())
predictions=np.array(predictions).flatten()
truth = np.array(truth).flatten()
print(classification_report(truth, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81      3793
#            1       0.52      0.44      0.48      2101
#            2       0.56      0.47      0.51      2830
#            3       0.58      0.57      0.57      5606
#            4       0.82      0.87      0.84     11270
#
#     accuracy                           0.72     25600
#    macro avg       0.65      0.64      0.64     25600
# weighted avg       0.71      0.72      0.71     25600

# %% [raw]
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81      3793
#            1       0.52      0.44      0.48      2101
#            2       0.56      0.47      0.51      2830
#            3       0.58      0.57      0.57      5606
#            4       0.82      0.87      0.84     11270
#
#     accuracy                           0.72     25600
#    macro avg       0.65      0.64      0.64     25600
# weighted avg       0.71      0.72      0.71     25600

# %%
confusion_matrix(truth, predictions, labels=[0, 1, 2, 3, 4])
# Out:
# array([[3182,  430,  100,   21,   60],
#        [ 589,  922,  452,   96,   42],
#        [ 139,  356, 1330,  875,  130],
#        [  47,   54,  418, 3185, 1902],
#        [  67,   17,   63, 1334, 9789]])

# %% [raw]
# array([[3182,  430,  100,   21,   60],
#        [ 589,  922,  452,   96,   42],
#        [ 139,  356, 1330,  875,  130],
#        [  47,   54,  418, 3185, 1902],
#        [  67,   17,   63, 1334, 9789]])

# %%
baby_embedding = baby.layers[1].get_weights()[0]
baby_dict = {key: baby_embedding[val] for key, val in keys_to_ix.items()}

# %%
dists, ix = neighbors(baby_dict['money'.encode()], baby_dict)
dists[dists.columns[ix]]

# %%
class TeenBerry:
    
    def build(dropout_rate, lstm_units, kernels, out_units, embedding_array):
        ix_input = Input(shape=(max_length,), name='review-ix')
        
        embedding = Embedding(input_dim=len(glove_lookup_array), output_dim=glove_dim, 
                              input_length=max_length, name='trained_embed', weights=[embedding_array])(ix_input)
        channel_embedding = Reshape(target_shape=(max_length, glove_dim, 1), name='reshape_embed')(embedding)
        
        branches = []
        names = {}
        for kernel in kernels:
            if (kernel['height'], kernel['width']) in names:
                names[(kernel['height'], kernel['width'])] = i = names[(kernel['height'], kernel['width'])] + 1
            else:
                names[(kernel['height'], kernel['width'])] = i = 1
            branch = Conv2D(kernel['filters'], (kernel['height'], kernel['width']), activation='relu', 
                            name='conv_{}_{}_{}'.format(kernel['height'], kernel['width'], i), 
                            padding='valid')(channel_embedding)
            branch = GlobalMaxPool2D(name='pool_{}_{}_{}'.format(kernel['height'], kernel['width'], i))(branch)
            branches.append(branch)
        
        lstm_out = LSTM(units=lstm_units, name='lstm')(embedding)
        x = Concatenate(name='concat_conv')(branches)
        
        x = Dropout(rate=dropout_rate, name='dropout')(x)
        x = Concatenate(name='concat_conv_lstm')([x, lstm_out])
        x = Dense(500, activation='relu', name='dense')(x)
        out = Dense(out_units, activation='softmax', name='stars')(x)
        
        return tf.keras.models.Model(inputs={'review-ix': ix_input}, 
                                     outputs={'stars': out}, name='TeenBerry')
        
    @tf.function
    def loss_fn(truth, logits):
        loss = tf.keras.losses.sparse_categorical_crossentropy(truth, logits)
        return loss

# %%
teen = TeenBerry.build(kernels=kernels, dropout_rate=.3, out_units=3, lstm_units=600, embedding_array=learned_embedding)
adam = tf.keras.optimizers.Adam()
teen.compile(optimizer=adam, metrics={'stars': star_metrics} ,loss={'stars': TeenBerry.loss_fn})
# Out:
# W0607 20:12:19.381424 139807149795136 tf_logging.py:161] <tensorflow.python.keras.layers.recurrent.UnifiedLSTM object at 0x7f267341f978>: Note that this layer is not optimized for performance. Please use tf.keras.layers.CuDNNLSTM for better performance on GPU.

# %%
plot_model(teen, show_shapes=True, rankdir='LR', to_file='teen_berry_model.png')

# %%
log_dir = os.path.join(SRC_DIR, 'logs', 'TeenBerry-{}'.format(datetime.fromtimestamp(time.time()).strftime('%d-%m_%H-%M-%S')))
tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir, write_graph=False, update_freq='batch')

# %%
_=teen.fit(dataset['train'], steps_per_epoch=200, epochs=50, 
                             validation_data= dataset['val'], validation_steps=20,
                             callbacks=[tb], class_weight=class_weights['ternary'], verbose=1)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.7285 - all_acc: 0.6620 - 0_recalll: 0.3974 - 1_recalll: 0.6336 - 2_recalll: 0.7704 - 0_precision: 0.4836 - 1_precision: 0.6396 - 2_precision: 0.6983 - val_loss: 0.5382 - val_all_acc: 0.7602 - val_0_recalll: 0.7536 - val_1_recalll: 0.6644 - val_2_recalll: 0.8548 - val_0_precision: 0.7538 - val_1_precision: 0.7616 - val_2_precision: 0.7608
# Epoch 2/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.5468 - all_acc: 0.7524 - 0_recalll: 0.7379 - 1_recalll: 0.6928 - 2_recalll: 0.8127 - 0_precision: 0.7501 - 1_precision: 0.7285 - 2_precision: 0.7810 - val_loss: 0.5084 - val_all_acc: 0.7715 - val_0_recalll: 0.7812 - val_1_recalll: 0.7716 - val_2_recalll: 0.7663 - val_0_precision: 0.7450 - val_1_precision: 0.7276 - val_2_precision: 0.8324
# Epoch 3/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.5228 - all_acc: 0.7689 - 0_recalll: 0.7846 - 1_recalll: 0.6921 - 2_recalll: 0.8323 - 0_precision: 0.7853 - 1_precision: 0.7343 - 2_precision: 0.7976 - val_loss: 0.4906 - val_all_acc: 0.7801 - val_0_recalll: 0.7862 - val_1_recalll: 0.7059 - val_2_recalll: 0.8501 - val_0_precision: 0.7905 - val_1_precision: 0.7714 - val_2_precision: 0.7853
# Epoch 4/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.4911 - all_acc: 0.7837 - 0_recalll: 0.8167 - 1_recalll: 0.6875 - 2_recalll: 0.8509 - 0_precision: 0.8130 - 1_precision: 0.7449 - 2_precision: 0.8061 - val_loss: 0.4858 - val_all_acc: 0.7809 - val_0_recalll: 0.7968 - val_1_recalll: 0.7105 - val_2_recalll: 0.8439 - val_0_precision: 0.7995 - val_1_precision: 0.7694 - val_2_precision: 0.7874
# Epoch 5/100
# 200/200 [==============================] - 39s 194ms/step - loss: 0.4903 - all_acc: 0.7831 - 0_recalll: 0.8135 - 1_recalll: 0.6898 - 2_recalll: 0.8528 - 0_precision: 0.7944 - 1_precision: 0.7468 - 2_precision: 0.8100 - val_loss: 0.4830 - val_all_acc: 0.7840 - val_0_recalll: 0.8355 - val_1_recalll: 0.6939 - val_2_recalll: 0.8547 - val_0_precision: 0.7551 - val_1_precision: 0.7851 - val_2_precision: 0.7955
# Epoch 6/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.4853 - all_acc: 0.7854 - 0_recalll: 0.7995 - 1_recalll: 0.7126 - 2_recalll: 0.8453 - 0_precision: 0.8046 - 1_precision: 0.7534 - 2_precision: 0.8105 - val_loss: 0.4913 - val_all_acc: 0.7762 - val_0_recalll: 0.8709 - val_1_recalll: 0.6063 - val_2_recalll: 0.9092 - val_0_precision: 0.7235 - val_1_precision: 0.8319 - val_2_precision: 0.7607
# Epoch 7/100
# 200/200 [==============================] - 39s 194ms/step - loss: 0.4786 - all_acc: 0.7892 - 0_recalll: 0.8215 - 1_recalll: 0.7020 - 2_recalll: 0.8540 - 0_precision: 0.8023 - 1_precision: 0.7582 - 2_precision: 0.8133 - val_loss: 0.4627 - val_all_acc: 0.7891 - val_0_recalll: 0.8605 - val_1_recalll: 0.7273 - val_2_recalll: 0.8238 - val_0_precision: 0.7606 - val_1_precision: 0.7759 - val_2_precision: 0.8145
# Epoch 8/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4786 - all_acc: 0.7912 - 0_recalll: 0.8247 - 1_recalll: 0.7091 - 2_recalll: 0.8519 - 0_precision: 0.8037 - 1_precision: 0.7618 - 2_precision: 0.8147 - val_loss: 0.4644 - val_all_acc: 0.7910 - val_0_recalll: 0.8419 - val_1_recalll: 0.6868 - val_2_recalll: 0.8756 - val_0_precision: 0.7942 - val_1_precision: 0.8055 - val_2_precision: 0.7819
# Epoch 9/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.4799 - all_acc: 0.7842 - 0_recalll: 0.7891 - 1_recalll: 0.7196 - 2_recalll: 0.8452 - 0_precision: 0.7931 - 1_precision: 0.7637 - 2_precision: 0.8019 - val_loss: 0.4619 - val_all_acc: 0.7895 - val_0_recalll: 0.7624 - val_1_recalll: 0.7214 - val_2_recalll: 0.8636 - val_0_precision: 0.8311 - val_1_precision: 0.7777 - val_2_precision: 0.7878
# Epoch 10/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.4778 - all_acc: 0.7882 - 0_recalll: 0.7826 - 1_recalll: 0.7329 - 2_recalll: 0.8432 - 0_precision: 0.7933 - 1_precision: 0.7644 - 2_precision: 0.8105 - val_loss: 0.4553 - val_all_acc: 0.7988 - val_0_recalll: 0.7776 - val_1_recalll: 0.7565 - val_2_recalll: 0.8489 - val_0_precision: 0.8330 - val_1_precision: 0.7784 - val_2_precision: 0.8097
# Epoch 11/100
# 200/200 [==============================] - 39s 196ms/step - loss: 0.4739 - all_acc: 0.7893 - 0_recalll: 0.7987 - 1_recalll: 0.7242 - 2_recalll: 0.8477 - 0_precision: 0.8013 - 1_precision: 0.7685 - 2_precision: 0.8068 - val_loss: 0.4677 - val_all_acc: 0.7895 - val_0_recalll: 0.8316 - val_1_recalll: 0.7395 - val_2_recalll: 0.8237 - val_0_precision: 0.7509 - val_1_precision: 0.7735 - val_2_precision: 0.8174
# Epoch 12/100
# 200/200 [==============================] - 39s 195ms/step - loss: 0.4704 - all_acc: 0.7922 - 0_recalll: 0.7843 - 1_recalll: 0.7301 - 2_recalll: 0.8543 - 0_precision: 0.7824 - 1_precision: 0.7740 - 2_precision: 0.8145 - val_loss: 0.4566 - val_all_acc: 0.7898 - val_0_recalll: 0.7574 - val_1_recalll: 0.7217 - val_2_recalll: 0.8670 - val_0_precision: 0.8292 - val_1_precision: 0.7753 - val_2_precision: 0.7923
# Epoch 13/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.4672 - all_acc: 0.7917 - 0_recalll: 0.7887 - 1_recalll: 0.7251 - 2_recalll: 0.8538 - 0_precision: 0.7871 - 1_precision: 0.7678 - 2_precision: 0.8163 - val_loss: 0.4554 - val_all_acc: 0.7910 - val_0_recalll: 0.7727 - val_1_recalll: 0.7197 - val_2_recalll: 0.8669 - val_0_precision: 0.8339 - val_1_precision: 0.7797 - val_2_precision: 0.7889
# Epoch 14/100
# 200/200 [==============================] - 39s 194ms/step - loss: 0.4616 - all_acc: 0.7943 - 0_recalll: 0.7768 - 1_recalll: 0.7339 - 2_recalll: 0.8562 - 0_precision: 0.7977 - 1_precision: 0.7714 - 2_precision: 0.8165 - val_loss: 0.4553 - val_all_acc: 0.7957 - val_0_recalll: 0.8578 - val_1_recalll: 0.7264 - val_2_recalll: 0.8421 - val_0_precision: 0.7590 - val_1_precision: 0.7922 - val_2_precision: 0.8130
# Epoch 15/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.4605 - all_acc: 0.7937 - 0_recalll: 0.7913 - 1_recalll: 0.7398 - 2_recalll: 0.8470 - 0_precision: 0.7998 - 1_precision: 0.7742 - 2_precision: 0.8138 - val_loss: 0.4519 - val_all_acc: 0.8004 - val_0_recalll: 0.7684 - val_1_recalll: 0.7867 - val_2_recalll: 0.8229 - val_0_precision: 0.8271 - val_1_precision: 0.7644 - val_2_precision: 0.8286
# Epoch 16/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.4622 - all_acc: 0.7908 - 0_recalll: 0.7806 - 1_recalll: 0.7361 - 2_recalll: 0.8482 - 0_precision: 0.7942 - 1_precision: 0.7728 - 2_precision: 0.8098 - val_loss: 0.4535 - val_all_acc: 0.7949 - val_0_recalll: 0.8273 - val_1_recalll: 0.7113 - val_2_recalll: 0.8656 - val_0_precision: 0.7714 - val_1_precision: 0.8020 - val_2_precision: 0.7987
# Epoch 17/100
# 200/200 [==============================] - 39s 195ms/step - loss: 0.4647 - all_acc: 0.7925 - 0_recalll: 0.7918 - 1_recalll: 0.7320 - 2_recalll: 0.8514 - 0_precision: 0.7844 - 1_precision: 0.7737 - 2_precision: 0.8160 - val_loss: 0.4484 - val_all_acc: 0.8012 - val_0_recalll: 0.8016 - val_1_recalll: 0.7472 - val_2_recalll: 0.8544 - val_0_precision: 0.8208 - val_1_precision: 0.7849 - val_2_precision: 0.8107
# Epoch 18/100
# 200/200 [==============================] - 39s 194ms/step - loss: 0.4645 - all_acc: 0.7901 - 0_recalll: 0.7861 - 1_recalll: 0.7305 - 2_recalll: 0.8499 - 0_precision: 0.7909 - 1_precision: 0.7715 - 2_precision: 0.8103 - val_loss: 0.4499 - val_all_acc: 0.7953 - val_0_recalll: 0.8308 - val_1_recalll: 0.7096 - val_2_recalll: 0.8663 - val_0_precision: 0.7708 - val_1_precision: 0.7966 - val_2_precision: 0.8029
# Epoch 19/100
# 200/200 [==============================] - 39s 194ms/step - loss: 0.4642 - all_acc: 0.7889 - 0_recalll: 0.7977 - 1_recalll: 0.7237 - 2_recalll: 0.8466 - 0_precision: 0.8000 - 1_precision: 0.7679 - 2_precision: 0.8076 - val_loss: 0.4472 - val_all_acc: 0.7980 - val_0_recalll: 0.8263 - val_1_recalll: 0.7093 - val_2_recalll: 0.8741 - val_0_precision: 0.7971 - val_1_precision: 0.8027 - val_2_precision: 0.7951
# Epoch 20/100
# 200/200 [==============================] - 39s 194ms/step - loss: 0.4618 - all_acc: 0.7943 - 0_recalll: 0.8012 - 1_recalll: 0.7279 - 2_recalll: 0.8527 - 0_precision: 0.8060 - 1_precision: 0.7714 - 2_precision: 0.8133 - val_loss: 0.4447 - val_all_acc: 0.7977 - val_0_recalll: 0.8098 - val_1_recalll: 0.7446 - val_2_recalll: 0.8452 - val_0_precision: 0.7926 - val_1_precision: 0.7785 - val_2_precision: 0.8196
# Epoch 21/100
# 200/200 [==============================] - 39s 194ms/step - loss: 0.4576 - all_acc: 0.7966 - 0_recalll: 0.7961 - 1_recalll: 0.7316 - 2_recalll: 0.8586 - 0_precision: 0.8099 - 1_precision: 0.7749 - 2_precision: 0.8126 - val_loss: 0.4469 - val_all_acc: 0.8031 - val_0_recalll: 0.8326 - val_1_recalll: 0.7416 - val_2_recalll: 0.8541 - val_0_precision: 0.7551 - val_1_precision: 0.7931 - val_2_precision: 0.8307
# Epoch 22/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4526 - all_acc: 0.8009 - 0_recalll: 0.7989 - 1_recalll: 0.7363 - 2_recalll: 0.8604 - 0_precision: 0.8072 - 1_precision: 0.7777 - 2_precision: 0.8201 - val_loss: 0.4392 - val_all_acc: 0.8066 - val_0_recalll: 0.8269 - val_1_recalll: 0.7519 - val_2_recalll: 0.8542 - val_0_precision: 0.7912 - val_1_precision: 0.7915 - val_2_precision: 0.8270
# Epoch 23/100
# 200/200 [==============================] - 39s 195ms/step - loss: 0.4547 - all_acc: 0.7975 - 0_recalll: 0.7875 - 1_recalll: 0.7327 - 2_recalll: 0.8614 - 0_precision: 0.8047 - 1_precision: 0.7733 - 2_precision: 0.8168 - val_loss: 0.4337 - val_all_acc: 0.8102 - val_0_recalll: 0.8257 - val_1_recalll: 0.7684 - val_2_recalll: 0.8458 - val_0_precision: 0.7990 - val_1_precision: 0.7874 - val_2_precision: 0.8379
# Epoch 24/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4472 - all_acc: 0.7992 - 0_recalll: 0.8084 - 1_recalll: 0.7236 - 2_recalll: 0.8611 - 0_precision: 0.8073 - 1_precision: 0.7725 - 2_precision: 0.8194 - val_loss: 0.4377 - val_all_acc: 0.8004 - val_0_recalll: 0.8699 - val_1_recalll: 0.7238 - val_2_recalll: 0.8511 - val_0_precision: 0.7541 - val_1_precision: 0.8012 - val_2_precision: 0.8187
# Epoch 25/100
# 200/200 [==============================] - 38s 191ms/step - loss: 0.4508 - all_acc: 0.8021 - 0_recalll: 0.8307 - 1_recalll: 0.7200 - 2_recalll: 0.8625 - 0_precision: 0.8153 - 1_precision: 0.7722 - 2_precision: 0.8249 - val_loss: 0.4365 - val_all_acc: 0.8012 - val_0_recalll: 0.8057 - val_1_recalll: 0.7204 - val_2_recalll: 0.8789 - val_0_precision: 0.8164 - val_1_precision: 0.8016 - val_2_precision: 0.7985
# Epoch 26/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4584 - all_acc: 0.7948 - 0_recalll: 0.8235 - 1_recalll: 0.7075 - 2_recalll: 0.8614 - 0_precision: 0.7991 - 1_precision: 0.7660 - 2_precision: 0.8176 - val_loss: 0.4473 - val_all_acc: 0.7980 - val_0_recalll: 0.8355 - val_1_recalll: 0.7777 - val_2_recalll: 0.8038 - val_0_precision: 0.7820 - val_1_precision: 0.7612 - val_2_precision: 0.8454
# Epoch 27/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4580 - all_acc: 0.7982 - 0_recalll: 0.8135 - 1_recalll: 0.7302 - 2_recalll: 0.8564 - 0_precision: 0.8044 - 1_precision: 0.7777 - 2_precision: 0.8155 - val_loss: 0.4432 - val_all_acc: 0.7980 - val_0_recalll: 0.8253 - val_1_recalll: 0.6938 - val_2_recalll: 0.8916 - val_0_precision: 0.7958 - val_1_precision: 0.8113 - val_2_precision: 0.7917
# Epoch 28/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4575 - all_acc: 0.7974 - 0_recalll: 0.7829 - 1_recalll: 0.7394 - 2_recalll: 0.8571 - 0_precision: 0.7990 - 1_precision: 0.7762 - 2_precision: 0.8174 - val_loss: 0.4323 - val_all_acc: 0.8020 - val_0_recalll: 0.8395 - val_1_recalll: 0.7055 - val_2_recalll: 0.8842 - val_0_precision: 0.7932 - val_1_precision: 0.8111 - val_2_precision: 0.7995
# Epoch 29/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.4543 - all_acc: 0.7961 - 0_recalll: 0.8019 - 1_recalll: 0.7379 - 2_recalll: 0.8507 - 0_precision: 0.7998 - 1_precision: 0.7782 - 2_precision: 0.8136 - val_loss: 0.4365 - val_all_acc: 0.8020 - val_0_recalll: 0.8483 - val_1_recalll: 0.7407 - val_2_recalll: 0.8469 - val_0_precision: 0.7828 - val_1_precision: 0.7890 - val_2_precision: 0.8212
# Epoch 30/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.4563 - all_acc: 0.7964 - 0_recalll: 0.7996 - 1_recalll: 0.7388 - 2_recalll: 0.8519 - 0_precision: 0.8018 - 1_precision: 0.7787 - 2_precision: 0.8148 - val_loss: 0.4369 - val_all_acc: 0.7973 - val_0_recalll: 0.8666 - val_1_recalll: 0.6871 - val_2_recalll: 0.8813 - val_0_precision: 0.7633 - val_1_precision: 0.8137 - val_2_precision: 0.7984
# Epoch 31/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4517 - all_acc: 0.7973 - 0_recalll: 0.8059 - 1_recalll: 0.7317 - 2_recalll: 0.8563 - 0_precision: 0.8012 - 1_precision: 0.7795 - 2_precision: 0.8125 - val_loss: 0.4342 - val_all_acc: 0.8008 - val_0_recalll: 0.8216 - val_1_recalll: 0.7684 - val_2_recalll: 0.8251 - val_0_precision: 0.8074 - val_1_precision: 0.7717 - val_2_precision: 0.8291
# Epoch 32/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4523 - all_acc: 0.7950 - 0_recalll: 0.8054 - 1_recalll: 0.7253 - 2_recalll: 0.8580 - 0_precision: 0.7976 - 1_precision: 0.7771 - 2_precision: 0.8117 - val_loss: 0.4276 - val_all_acc: 0.8109 - val_0_recalll: 0.8163 - val_1_recalll: 0.7436 - val_2_recalll: 0.8740 - val_0_precision: 0.8227 - val_1_precision: 0.8050 - val_2_precision: 0.8149
# Epoch 33/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4509 - all_acc: 0.8006 - 0_recalll: 0.7944 - 1_recalll: 0.7446 - 2_recalll: 0.8590 - 0_precision: 0.7983 - 1_precision: 0.7833 - 2_precision: 0.8188 - val_loss: 0.4335 - val_all_acc: 0.8078 - val_0_recalll: 0.8416 - val_1_recalll: 0.7795 - val_2_recalll: 0.8241 - val_0_precision: 0.7957 - val_1_precision: 0.7772 - val_2_precision: 0.8477
# Epoch 34/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4502 - all_acc: 0.8006 - 0_recalll: 0.8093 - 1_recalll: 0.7375 - 2_recalll: 0.8576 - 0_precision: 0.8027 - 1_precision: 0.7822 - 2_precision: 0.8190 - val_loss: 0.4352 - val_all_acc: 0.8043 - val_0_recalll: 0.8318 - val_1_recalll: 0.7132 - val_2_recalll: 0.8844 - val_0_precision: 0.7801 - val_1_precision: 0.8124 - val_2_precision: 0.8087
# Epoch 35/100
# 200/200 [==============================] - 39s 194ms/step - loss: 0.4437 - all_acc: 0.8018 - 0_recalll: 0.8075 - 1_recalll: 0.7394 - 2_recalll: 0.8580 - 0_precision: 0.8063 - 1_precision: 0.7793 - 2_precision: 0.8223 - val_loss: 0.4339 - val_all_acc: 0.8094 - val_0_recalll: 0.7661 - val_1_recalll: 0.7607 - val_2_recalll: 0.8712 - val_0_precision: 0.8399 - val_1_precision: 0.7930 - val_2_precision: 0.8179
# Epoch 36/100
# 200/200 [==============================] - 39s 195ms/step - loss: 0.4482 - all_acc: 0.7993 - 0_recalll: 0.7916 - 1_recalll: 0.7346 - 2_recalll: 0.8627 - 0_precision: 0.7960 - 1_precision: 0.7787 - 2_precision: 0.8209 - val_loss: 0.4295 - val_all_acc: 0.8047 - val_0_recalll: 0.7867 - val_1_recalll: 0.7719 - val_2_recalll: 0.8422 - val_0_precision: 0.8234 - val_1_precision: 0.7754 - val_2_precision: 0.8310
# Epoch 37/100
# 200/200 [==============================] - 39s 194ms/step - loss: 0.4431 - all_acc: 0.8024 - 0_recalll: 0.8080 - 1_recalll: 0.7397 - 2_recalll: 0.8593 - 0_precision: 0.8047 - 1_precision: 0.7812 - 2_precision: 0.8222 - val_loss: 0.4312 - val_all_acc: 0.8059 - val_0_recalll: 0.8749 - val_1_recalll: 0.7344 - val_2_recalll: 0.8526 - val_0_precision: 0.7720 - val_1_precision: 0.8050 - val_2_precision: 0.8196
# Epoch 38/100
# 200/200 [==============================] - 39s 195ms/step - loss: 0.4523 - all_acc: 0.7998 - 0_recalll: 0.7948 - 1_recalll: 0.7404 - 2_recalll: 0.8562 - 0_precision: 0.8049 - 1_precision: 0.7788 - 2_precision: 0.8215 - val_loss: 0.4308 - val_all_acc: 0.8105 - val_0_recalll: 0.7933 - val_1_recalll: 0.7645 - val_2_recalll: 0.8615 - val_0_precision: 0.8155 - val_1_precision: 0.7936 - val_2_precision: 0.8256
# Epoch 39/100
# 200/200 [==============================] - 39s 194ms/step - loss: 0.4576 - all_acc: 0.7967 - 0_recalll: 0.7924 - 1_recalll: 0.7417 - 2_recalll: 0.8524 - 0_precision: 0.7953 - 1_precision: 0.7799 - 2_precision: 0.8184 - val_loss: 0.4542 - val_all_acc: 0.8004 - val_0_recalll: 0.8537 - val_1_recalll: 0.7878 - val_2_recalll: 0.7949 - val_0_precision: 0.7667 - val_1_precision: 0.7661 - val_2_precision: 0.8521
# Epoch 40/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.4568 - all_acc: 0.7948 - 0_recalll: 0.7875 - 1_recalll: 0.7338 - 2_recalll: 0.8550 - 0_precision: 0.7896 - 1_precision: 0.7752 - 2_precision: 0.8143 - val_loss: 0.4494 - val_all_acc: 0.7992 - val_0_recalll: 0.8869 - val_1_recalll: 0.7709 - val_2_recalll: 0.7986 - val_0_precision: 0.7432 - val_1_precision: 0.7742 - val_2_precision: 0.8498
# Epoch 41/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.4484 - all_acc: 0.7987 - 0_recalll: 0.8030 - 1_recalll: 0.7297 - 2_recalll: 0.8611 - 0_precision: 0.8001 - 1_precision: 0.7805 - 2_precision: 0.8187 - val_loss: 0.4339 - val_all_acc: 0.8078 - val_0_recalll: 0.8139 - val_1_recalll: 0.8018 - val_2_recalll: 0.8117 - val_0_precision: 0.8101 - val_1_precision: 0.7678 - val_2_precision: 0.8519
# Epoch 42/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4501 - all_acc: 0.7968 - 0_recalll: 0.8014 - 1_recalll: 0.7376 - 2_recalll: 0.8521 - 0_precision: 0.8012 - 1_precision: 0.7781 - 2_precision: 0.8161 - val_loss: 0.4344 - val_all_acc: 0.8062 - val_0_recalll: 0.8168 - val_1_recalll: 0.8045 - val_2_recalll: 0.8035 - val_0_precision: 0.8109 - val_1_precision: 0.7606 - val_2_precision: 0.8556
# Epoch 43/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4471 - all_acc: 0.8009 - 0_recalll: 0.8018 - 1_recalll: 0.7353 - 2_recalll: 0.8625 - 0_precision: 0.8028 - 1_precision: 0.7797 - 2_precision: 0.8217 - val_loss: 0.4322 - val_all_acc: 0.8078 - val_0_recalll: 0.8697 - val_1_recalll: 0.7234 - val_2_recalll: 0.8708 - val_0_precision: 0.7765 - val_1_precision: 0.8128 - val_2_precision: 0.8174
# Epoch 44/100
# 200/200 [==============================] - 39s 194ms/step - loss: 0.4410 - all_acc: 0.8052 - 0_recalll: 0.8443 - 1_recalll: 0.7197 - 2_recalll: 0.8652 - 0_precision: 0.8248 - 1_precision: 0.7768 - 2_precision: 0.8231 - val_loss: 0.4228 - val_all_acc: 0.8109 - val_0_recalll: 0.8308 - val_1_recalll: 0.7593 - val_2_recalll: 0.8536 - val_0_precision: 0.8172 - val_1_precision: 0.7930 - val_2_precision: 0.8269
# Epoch 45/100
#   4/200 [..............................] - ETA: 35s - loss: 0.3990 - all_acc: 0.8477 - 0_recalll: 0.8943 - 1_recalll: 0.7663 - 2_recalll: 0.8943 - 0_precision: 0.8290 - 1_precision: 0.8190 - 2_precision: 0.8716
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-123-d3ab9ca6abf0> in <module>
#       1 _=teen.fit(dataset['train'], steps_per_epoch=200, epochs=100,
#       2                              validation_data= dataset['val'], validation_steps=20,
# ----> 3                              callbacks=[tb], class_weight=class_weights['ternary'], verbose=1)
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     789           workers=0,
#     790           shuffle=shuffle,
# --> 791           initial_epoch=initial_epoch)
#     792
#     793     # Case 3: Symbolic tensors or Numpy array-like.
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1513         shuffle=shuffle,
#    1514         initial_epoch=initial_epoch,
# -> 1515         steps_name='steps_per_epoch')
#    1516
#    1517   def evaluate_generator(self,
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     255
#     256       is_deferred = not model._is_compiled
# --> 257       batch_outs = batch_function(*batch_data)
#     258       if not isinstance(batch_outs, list):
#     259         batch_outs = [batch_outs]
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1245           sample_weights=sample_weights,
#    1246           reset_metrics=reset_metrics,
# -> 1247           output_loss_metrics=self._output_loss_metrics)
#    1248     else:
#    1249       if not isinstance(K.symbolic_learning_phase(), int):
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_eager.py in train_on_batch(model, inputs, targets, sample_weights, reset_metrics, output_loss_metrics)
#     293           sample_weights=sample_weights,
#     294           training=True,
# --> 295           output_loss_metrics=output_loss_metrics))
#     296   if not isinstance(outs, list):
#     297     outs = [outs]
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_eager.py in _process_single_batch(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     233               output_loss_metrics=output_loss_metrics,
#     234               sample_weights=sample_weights,
# --> 235               training=training))
#     236       if total_loss is None:
#     237         raise ValueError('The model cannot be run '
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_eager.py in _model_loss(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     114     inputs = nest.map_structure(ops.convert_to_tensor, inputs)
#     115
# --> 116   outs = model(inputs, **kwargs)
#     117
#     118   outs = nest.flatten(outs)
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     658           with base_layer_utils.autocast_context_manager(
#     659               input_list, self._mixed_precision_policy.should_cast_variables):
# --> 660             outputs = self.call(inputs, *args, **kwargs)
#     661           self._handle_activity_regularization(inputs, outputs)
#     662           self._set_mask_metadata(inputs, outputs, previous_mask)
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/network.py in call(self, inputs, training, mask)
#     868                                 ' implement a `call` method.')
#     869
# --> 870     return self._run_internal_graph(inputs, training=training, mask=mask)
#     871
#     872   def compute_output_shape(self, input_shape):
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/network.py in _run_internal_graph(self, inputs, training, mask)
#    1009
#    1010           # Compute outputs.
# -> 1011           output_tensors = layer(computed_tensors, **kwargs)
#    1012
#    1013           # Update tensor_dict.
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     656
#     657     if initial_state is None and constants is None:
# --> 658       return super(RNN, self).__call__(inputs, **kwargs)
#     659
#     660     # If any of `initial_state` or `constants` are specified and are Keras
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     658           with base_layer_utils.autocast_context_manager(
#     659               input_list, self._mixed_precision_policy.should_cast_variables):
# --> 660             outputs = self.call(inputs, *args, **kwargs)
#     661           self._handle_activity_regularization(inputs, outputs)
#     662           self._set_mask_metadata(inputs, outputs, previous_mask)
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent.py in call(self, inputs, mask, training, initial_state)
#    3216   def call(self, inputs, mask=None, training=None, initial_state=None):
#    3217     # LSTM does not support constants. Ignore it during process.
# -> 3218     inputs, initial_state, _ = self._process_inputs(inputs, initial_state, None)
#    3219
#    3220     if isinstance(mask, list):
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent.py in _process_inputs(self, inputs, initial_state, constants)
#     821       initial_state = self.states
#     822     else:
# --> 823       initial_state = self.get_initial_state(inputs)
#     824
#     825     if len(initial_state) != len(self.states):
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent.py in get_initial_state(self, inputs)
#     629       inputs = nest.flatten(inputs)[0]
#     630
# --> 631     input_shape = array_ops.shape(inputs)
#     632     batch_size = input_shape[1] if self.time_major else input_shape[0]
#     633     dtype = inputs.dtype
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in shape(input, name, out_type)
#     311     A `Tensor` of type `out_type`.
#     312   """
# --> 313   return shape_internal(input, name, optimize=True, out_type=out_type)
#     314
#     315
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in shape_internal(input, name, optimize, out_type)
#     339         if optimize and input_shape.is_fully_defined():
#     340           return constant(input_shape.as_list(), out_type, name=name)
# --> 341       return gen_array_ops.shape(input, name=name, out_type=out_type)
#     342
#     343
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/ops/gen_array_ops.py in shape(input, out_type, name)
#    8402       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#    8403         _ctx._context_handle, _ctx._thread_local_data.device_name, "Shape",
# -> 8404         name, _ctx._post_execution_callbacks, input, "out_type", out_type)
#    8405       return _result
#    8406     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
truth, predictions = [], []
for x, y in dataset['val'].take(100):
    pred = teen(x['review-ix'])
    truth.append(y['stars'].numpy())
    predictions.append(tf.argmax(pred['stars'], axis=-1).numpy())
predictions=np.array(predictions).flatten()
truth = np.array(truth).flatten()
print(classification_report(truth, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80      1833
#            1       0.77      0.77      0.77      5373
#            2       0.83      0.84      0.84      5594
#
#     accuracy                           0.80     12800
#    macro avg       0.81      0.80      0.80     12800
# weighted avg       0.80      0.80      0.80     12800

# %% [raw]
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80      1833
#            1       0.77      0.77      0.77      5373
#            2       0.83      0.84      0.84      5594
#
#     accuracy                           0.80     12800
#    macro avg       0.81      0.80      0.80     12800
# weighted avg       0.80      0.80      0.80     12800

# %%
teen_embedding = teen.layers[1].get_weights()[0]
teen_dict = {key: teen_embedding[val] for key, val in keys_to_ix.items()}

# %%
teen_dists, teen_ix = neighbors(teen_dict['pizza'.encode()], teen_dict)
teen_dists[teen_dists.columns[teen_ix]]
# Out:
#    b'pizza'  b'bitsy'  b'butterfish'  b'so-and-so'  b'poundcake'  b'tatin'  \
# 0       0.0    0.3149       0.341596      0.342599      0.356102  0.358983
#
#     b'ravi'  b'rumpled'    b'ncl'  b'botanical'  ...  b'chagas'  b'prides'  \
# 0  0.359614    0.368764  0.369737      0.372811  ...   1.609885   1.618371
#
#      b'dcd'  b'segunda'    b'toy'  b'tenets'    b'10k'  b'recco'  b'clicking'  \
# 0  1.625978    1.627291  1.638852   1.640563  1.640691   1.64401     1.649442
#
#    b'anatomy'
# 0    1.663991
#
# [1 rows x 170431 columns]

# %%
class MatureBerry:
    
    def build(dropout_rate, lstm_units, kernels, out_units, embedding_array):
        ix_input = Input(shape=(max_length,), name='review-ix')
        
        embedding = Embedding(input_dim=len(glove_lookup_array), output_dim=glove_dim, 
                              input_length=max_length, name='trained_embed', weights=[embedding_array], trainable=False)(ix_input)
        
        channel_embedding = Reshape(target_shape=(max_length, glove_dim, 1), name='reshape_embed')(embedding)
        
        branches = []
        names = {}
        for kernel in kernels:
            if (kernel['height'], kernel['width']) in names:
                names[(kernel['height'], kernel['width'])] = i = names[(kernel['height'], kernel['width'])] + 1
            else:
                names[(kernel['height'], kernel['width'])] = i = 1
            branch = Conv2D(kernel['filters'], (kernel['height'], kernel['width']), activation='relu', 
                            name='conv_{}_{}_{}'.format(kernel['height'], kernel['width'], i), 
                            padding='valid')(channel_embedding)
            branch = GlobalMaxPool2D(name='pool_{}_{}_{}'.format(kernel['height'], kernel['width'], i))(branch)
            branches.append(branch)
        
#         lstm_out = LSTM(units=lstm_units, name='lstm')(embedding)
        x = Concatenate(name='concat_conv')(branches)
        
        x = Dropout(rate=dropout_rate, name='dropout')(x)
#         x = Concatenate(name='concat_conv_lstm')([x, lstm_out])
        x = Dense(500, activation='relu', name='dense')(x)
        out = Dense(out_units, activation='softmax', name='stars')(x)
        
        return tf.keras.models.Model(inputs={'review-ix': ix_input}, 
                                     outputs={'stars': out}, name='MatureBerry')
        
    @tf.function
    def loss_fn(truth, logits):
        loss = tf.keras.losses.sparse_categorical_crossentropy(truth, logits)
        return loss

# %%
mature = MatureBerry.build(kernels=kernels, dropout_rate=.2, out_units=5, lstm_units=600, embedding_array=teen_embedding)
adam = tf.keras.optimizers.Adam()
mature.compile(optimizer=adam, metrics={'stars': star_metrics} ,loss={'stars': MatureBerry.loss_fn})

# %%
plot_model(mature, show_shapes=True, rankdir='LR', to_file='mature_berry_model.png')

# %%
log_dir = os.path.join(SRC_DIR, 'logs', 'MatureBerry-{}'.format(datetime.fromtimestamp(time.time()).strftime('%d-%m_%H-%M-%S')))
tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir, write_graph=False, update_freq='batch')

# %%
_=mature.fit(dataset['train'], steps_per_epoch=200, epochs=50, 
                             validation_data= dataset['val'], validation_steps=20,
                             callbacks=[tb], class_weight=class_weights['five'], verbose=1)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 22s 109ms/step - loss: 1.3257 - all_acc: 0.4632 - 0_recalll: 0.1201 - 1_recalll: 0.0000e+00 - 2_recalll: 0.0059 - 3_recalll: 0.0443 - 4_recalll: 0.9742 - 0_precision: 0.1739 - 1_precision: 0.0000e+00 - 2_precision: 0.0457 - 3_precision: 0.1223 - 4_precision: 0.4752 - val_loss: 1.1646 - val_all_acc: 0.5172 - val_0_recalll: 0.2848 - val_1_recalll: 0.0000e+00 - val_2_recalll: 0.0576 - val_3_recalll: 0.3654 - val_4_recalll: 0.8746 - val_0_precision: 0.6750 - val_1_precision: 0.0000e+00 - val_2_precision: 0.2600 - val_3_precision: 0.3114 - val_4_precision: 0.5848
# Epoch 2/50
# 200/200 [==============================] - 22s 111ms/step - loss: 1.0552 - all_acc: 0.5667 - 0_recalll: 0.6899 - 1_recalll: 0.0152 - 2_recalll: 0.1940 - 3_recalll: 0.3190 - 4_recalll: 0.8407 - 0_precision: 0.5265 - 1_precision: 0.0938 - 2_precision: 0.3552 - 3_precision: 0.4251 - 4_precision: 0.6514 - val_loss: 0.9562 - val_all_acc: 0.6004 - val_0_recalll: 0.7106 - val_1_recalll: 0.0410 - val_2_recalll: 0.2376 - val_3_recalll: 0.2953 - val_4_recalll: 0.8972 - val_0_precision: 0.6253 - val_1_precision: 0.2508 - val_2_precision: 0.3768 - val_3_precision: 0.4447 - val_4_precision: 0.6585
# Epoch 3/50
# 200/200 [==============================] - 22s 110ms/step - loss: 0.9552 - all_acc: 0.6066 - 0_recalll: 0.7784 - 1_recalll: 0.0857 - 2_recalll: 0.2387 - 3_recalll: 0.3231 - 4_recalll: 0.8546 - 0_precision: 0.6138 - 1_precision: 0.2826 - 2_precision: 0.3638 - 3_precision: 0.4447 - 4_precision: 0.6941 - val_loss: 0.8922 - val_all_acc: 0.6258 - val_0_recalll: 0.8459 - val_1_recalll: 0.1030 - val_2_recalll: 0.2508 - val_3_recalll: 0.3140 - val_4_recalll: 0.8850 - val_0_precision: 0.6036 - val_1_precision: 0.3546 - val_2_precision: 0.4639 - val_3_precision: 0.4674 - val_4_precision: 0.6979
# Epoch 4/50
# 200/200 [==============================] - 22s 109ms/step - loss: 0.9101 - all_acc: 0.6254 - 0_recalll: 0.8159 - 1_recalll: 0.1149 - 2_recalll: 0.2448 - 3_recalll: 0.3458 - 4_recalll: 0.8541 - 0_precision: 0.6603 - 1_precision: 0.3371 - 2_precision: 0.3797 - 3_precision: 0.4592 - 4_precision: 0.7094 - val_loss: 0.8874 - val_all_acc: 0.6262 - val_0_recalll: 0.9174 - val_1_recalll: 0.0899 - val_2_recalll: 0.1479 - val_3_recalll: 0.2638 - val_4_recalll: 0.9172 - val_0_precision: 0.5743 - val_1_precision: 0.3767 - val_2_precision: 0.5406 - val_3_precision: 0.4770 - val_4_precision: 0.6910
# Epoch 5/50
# 200/200 [==============================] - 22s 110ms/step - loss: 0.8720 - all_acc: 0.6441 - 0_recalll: 0.8390 - 1_recalll: 0.1482 - 2_recalll: 0.2735 - 3_recalll: 0.3480 - 4_recalll: 0.8674 - 0_precision: 0.6718 - 1_precision: 0.3812 - 2_precision: 0.4028 - 3_precision: 0.4694 - 4_precision: 0.7321 - val_loss: 0.8502 - val_all_acc: 0.6496 - val_0_recalll: 0.7529 - val_1_recalll: 0.1409 - val_2_recalll: 0.3322 - val_3_recalll: 0.3823 - val_4_recalll: 0.9130 - val_0_precision: 0.7451 - val_1_precision: 0.3929 - val_2_precision: 0.4262 - val_3_precision: 0.4940 - val_4_precision: 0.7125
# Epoch 6/50
# 200/200 [==============================] - 22s 111ms/step - loss: 0.8633 - all_acc: 0.6422 - 0_recalll: 0.8269 - 1_recalll: 0.1810 - 2_recalll: 0.3118 - 3_recalll: 0.3809 - 4_recalll: 0.8638 - 0_precision: 0.6884 - 1_precision: 0.3779 - 2_precision: 0.4123 - 3_precision: 0.4824 - 4_precision: 0.7363 - val_loss: 0.8316 - val_all_acc: 0.6523 - val_0_recalll: 0.8910 - val_1_recalll: 0.1840 - val_2_recalll: 0.3328 - val_3_recalll: 0.2490 - val_4_recalll: 0.9289 - val_0_precision: 0.6447 - val_1_precision: 0.4062 - val_2_precision: 0.4924 - val_3_precision: 0.5865 - val_4_precision: 0.7038
# Epoch 7/50
# 200/200 [==============================] - 22s 110ms/step - loss: 0.8472 - all_acc: 0.6496 - 0_recalll: 0.8296 - 1_recalll: 0.2017 - 2_recalll: 0.2872 - 3_recalll: 0.3877 - 4_recalll: 0.8686 - 0_precision: 0.6853 - 1_precision: 0.4042 - 2_precision: 0.4183 - 3_precision: 0.4898 - 4_precision: 0.7426 - val_loss: 0.8065 - val_all_acc: 0.6652 - val_0_recalll: 0.8683 - val_1_recalll: 0.2587 - val_2_recalll: 0.3180 - val_3_recalll: 0.4324 - val_4_recalll: 0.8703 - val_0_precision: 0.6695 - val_1_precision: 0.4400 - val_2_precision: 0.4801 - val_3_precision: 0.5272 - val_4_precision: 0.7663
# Epoch 8/50
# 200/200 [==============================] - 22s 111ms/step - loss: 0.8475 - all_acc: 0.6501 - 0_recalll: 0.8402 - 1_recalll: 0.1796 - 2_recalll: 0.3218 - 3_recalll: 0.3989 - 4_recalll: 0.8613 - 0_precision: 0.6898 - 1_precision: 0.4078 - 2_precision: 0.4295 - 3_precision: 0.4934 - 4_precision: 0.7436 - val_loss: 0.8000 - val_all_acc: 0.6641 - val_0_recalll: 0.7969 - val_1_recalll: 0.3144 - val_2_recalll: 0.4340 - val_3_recalll: 0.3201 - val_4_recalll: 0.9093 - val_0_precision: 0.7395 - val_1_precision: 0.4316 - val_2_precision: 0.4485 - val_3_precision: 0.5578 - val_4_precision: 0.7371
# Epoch 9/50
# 200/200 [==============================] - 22s 110ms/step - loss: 0.8533 - all_acc: 0.6426 - 0_recalll: 0.8044 - 1_recalll: 0.2434 - 2_recalll: 0.3572 - 3_recalll: 0.4053 - 4_recalll: 0.8570 - 0_precision: 0.6824 - 1_precision: 0.4218 - 2_precision: 0.4548 - 3_precision: 0.5047 - 4_precision: 0.7361 - val_loss: 0.7885 - val_all_acc: 0.6695 - val_0_recalll: 0.8464 - val_1_recalll: 0.2630 - val_2_recalll: 0.4298 - val_3_recalll: 0.3667 - val_4_recalll: 0.8901 - val_0_precision: 0.7005 - val_1_precision: 0.4561 - val_2_precision: 0.4621 - val_3_precision: 0.5497 - val_4_precision: 0.7532
# Epoch 10/50
# 200/200 [==============================] - 22s 110ms/step - loss: 0.8500 - all_acc: 0.6450 - 0_recalll: 0.8052 - 1_recalll: 0.2362 - 2_recalll: 0.3665 - 3_recalll: 0.4252 - 4_recalll: 0.8570 - 0_precision: 0.6777 - 1_precision: 0.4064 - 2_precision: 0.4564 - 3_precision: 0.5086 - 4_precision: 0.7485 - val_loss: 0.8599 - val_all_acc: 0.6371 - val_0_recalll: 0.8806 - val_1_recalll: 0.2877 - val_2_recalll: 0.5422 - val_3_recalll: 0.3910 - val_4_recalll: 0.7621 - val_0_precision: 0.6644 - val_1_precision: 0.3807 - val_2_precision: 0.3583 - val_3_precision: 0.5074 - val_4_precision: 0.8289
# Epoch 11/50
# 200/200 [==============================] - 22s 111ms/step - loss: 0.8296 - all_acc: 0.6541 - 0_recalll: 0.8214 - 1_recalll: 0.2171 - 2_recalll: 0.3863 - 3_recalll: 0.4279 - 4_recalll: 0.8580 - 0_precision: 0.6894 - 1_precision: 0.4153 - 2_precision: 0.4669 - 3_precision: 0.5181 - 4_precision: 0.7490 - val_loss: 0.7772 - val_all_acc: 0.6758 - val_0_recalll: 0.8660 - val_1_recalll: 0.2161 - val_2_recalll: 0.4429 - val_3_recalll: 0.4724 - val_4_recalll: 0.8504 - val_0_precision: 0.7061 - val_1_precision: 0.4407 - val_2_precision: 0.4567 - val_3_precision: 0.5390 - val_4_precision: 0.7907
# Epoch 12/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.8265 - all_acc: 0.6510 - 0_recalll: 0.8122 - 1_recalll: 0.2371 - 2_recalll: 0.3684 - 3_recalll: 0.4176 - 4_recalll: 0.8632 - 0_precision: 0.6879 - 1_precision: 0.4281 - 2_precision: 0.4536 - 3_precision: 0.5047 - 4_precision: 0.7521
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-187-a7aa8f9d9daa> in <module>
#       1 _=mature.fit(dataset['train'], steps_per_epoch=200, epochs=50,
#       2                              validation_data= dataset['val'], validation_steps=20,
# ----> 3                              callbacks=[tb], class_weight=class_weights['five'], verbose=1)
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     789           workers=0,
#     790           shuffle=shuffle,
# --> 791           initial_epoch=initial_epoch)
#     792
#     793     # Case 3: Symbolic tensors or Numpy array-like.
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1513         shuffle=shuffle,
#    1514         initial_epoch=initial_epoch,
# -> 1515         steps_name='steps_per_epoch')
#    1516
#    1517   def evaluate_generator(self,
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     313           verbose=0,
#     314           mode=ModeKeys.TEST,
# --> 315           steps_name='validation_steps')
#     316
#     317       if not isinstance(val_results, list):
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     255
#     256       is_deferred = not model._is_compiled
# --> 257       batch_outs = batch_function(*batch_data)
#     258       if not isinstance(batch_outs, list):
#     259         batch_outs = [batch_outs]
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in test_on_batch(self, x, y, sample_weight, reset_metrics)
#    1319           sample_weights=sample_weights,
#    1320           reset_metrics=reset_metrics,
# -> 1321           output_loss_metrics=self._output_loss_metrics)
#    1322     else:
#    1323       inputs = x + y + sample_weights
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_eager.py in test_on_batch(model, inputs, targets, sample_weights, reset_metrics, output_loss_metrics)
#     365       sample_weights=sample_weights,
#     366       masks=masks,
# --> 367       return_stateful_result=not reset_metrics)
#     368   total_loss = nest.flatten(total_loss)
#     369   if reset_metrics:
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_eager.py in _eager_metrics_fn(model, outputs, targets, sample_weights, masks, return_stateful_result)
#      69       sample_weights=sample_weights,
#      70       masks=masks,
# ---> 71       return_stateful_result=return_stateful_result)
#      72   return [backend.mean(t) for t in metric_results]
#      73
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _handle_metrics(self, outputs, skip_target_indices, targets, sample_weights, masks, return_stateful_result)
#    2096                 output,
#    2097                 output_mask,
# -> 2098                 return_stateful_result=return_stateful_result))
#    2099         metric_results.extend(
#    2100             self._handle_per_output_metrics(
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _handle_per_output_metrics(self, metrics_dict, y_true, y_pred, mask, weights, return_stateful_result)
#    2045           # given fn or its stateful version based on the given flag.
#    2046           if return_stateful_result:
# -> 2047             metric_result = _call_stateful_fn(stateful_fn)
#    2048           else:
#    2049             metric_result = _call_stateless_fn(metric_fn)
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _call_stateful_fn(fn)
#    2025         def _call_stateful_fn(fn):
#    2026           """Create stateful metrics correctly."""
# -> 2027           return self._call_metric_fn(fn, y_true, y_pred, weights, mask)
#    2028
#    2029         def _call_stateless_fn(fn):
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _call_metric_fn(self, metric_fn, y_true, y_pred, weights, mask)
#    1983         y_pred,
#    1984         weights=weights,
# -> 1985         mask=mask)
#    1986
#    1987   def _call_fn_for_each_replica(self, fn, *args, **kwargs):
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _call_fn_for_each_replica(self, fn, *args, **kwargs)
#    1996         return self._distribution_strategy.extended.call_for_each_replica(
#    1997             fn, args, kwargs)
# -> 1998     return fn(*args, **kwargs)
#    1999
#    2000   def _handle_per_output_metrics(self,
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_utils.py in call_metric_function(metric_fn, y_true, y_pred, weights, mask)
#     892   """Invokes metric function and returns the metric result tensor."""
#     893   if mask is None:
# --> 894     return metric_fn(y_true, y_pred, sample_weight=weights)
#     895
#     896   mask = math_ops.cast(mask, y_pred.dtype)
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/metrics.py in __call__(self, *args, **kwargs)
#     168       The metric value tensor.
#     169     """
# --> 170     update_op = self.update_state(*args, **kwargs)  # pylint: disable=not-callable
#     171     with ops.control_dependencies([update_op]):
#     172       result_t = self.result()  # pylint: disable=not-callable
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/utils/metrics_utils.py in decorated(metric_obj, *args, **kwargs)
#      69     """Decorated function with `add_update()`."""
#      70
# ---> 71     update_op = update_state_fn(*args, **kwargs)
#      72     if update_op is not None:  # update_op will be None in eager execution.
#      73       metric_obj.add_update(update_op, inputs=True)
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/metrics.py in update_state(self, y_true, y_pred, sample_weight)
#     547         y_pred, y_true, sample_weight)
#     548
# --> 549     matches = self._fn(y_true, y_pred, **self._fn_kwargs)
#     550     return super(MeanMetricWrapper, self).update_state(
#     551         matches, sample_weight=sample_weight)
#
# <ipython-input-23-97b6acc3a91c> in single_class_precision(y_true, y_pred)
#      20         truth = K.flatten(K.cast(y_true, 'int32'))
#      21         preds = K.cast(K.argmax(y_pred, axis=-1), 'int32')
# ---> 22         precision_mask = K.cast(K.equal(preds, label), 'int32')
#      23         precision = K.cast(K.equal(preds, truth), 'int32') * precision_mask
#      24         precision = K.cast(K.sum(precision) / K.maximum(K.sum(precision_mask), 1), 'float32')
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in equal(x, y)
#    2005       A bool tensor.
#    2006   """
# -> 2007   return math_ops.equal(x, y)
#    2008
#    2009
#
# ~/anaconda3/envs/yelp-nlu_3.6/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in equal(x, y, name)
#    3270       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#    3271         _ctx._context_handle, _ctx._thread_local_data.device_name, "Equal",
# -> 3272         name, _ctx._post_execution_callbacks, x, y)
#    3273       return _result
#    3274     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
truth, predictions = [], []
for x, y in dataset['val'].take(100):
    pred = mature(x['review-ix'])
    truth.append(y['stars'].numpy())
    predictions.append(tf.argmax(pred['stars'], axis=-1).numpy())
predictions=np.array(predictions).flatten()
truth = np.array(truth).flatten()
print(classification_report(truth, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.75      1833
#            1       0.76      0.71      0.73      5373
#            2       0.79      0.86      0.82      5594
#
#     accuracy                           0.78     12800
#    macro avg       0.78      0.76      0.77     12800
# weighted avg       0.78      0.78      0.77     12800

# %%
mature_embedding = mature.layers[1].get_weights()[0]
mature_dict = {key: mature_embedding[val] for key, val in keys_to_ix.items()}

# %%
mature_dists, mature_ix = neighbors(mature_dict['loved'.encode()], mature_dict)
mature_dists[mature_dists.columns[mature_ix]]
# Out:
#    b'loved'  b'elazar'  b'patro'  b'tubule'  b'mines'  b'washlet'  b'sadie'  \
# 0       0.0   0.384605  0.405863   0.463439  0.471407    0.473811  0.475946
#
#    b'autem'   b'weft'  b'straten'  ...  b'zoldan'  b'paradies'  b'speros'  \
# 0  0.481688  0.483669    0.487023  ...   1.522145     1.524322   1.526691
#
#    b'ultras'  b'shuttering'  b'mealey'  b'limelight'  b'javale'  b'flatter'  \
# 0   1.528715       1.533502   1.537298      1.543703   1.550598    1.584278
#
#    b'perrault'
# 0     1.597305
#
# [1 rows x 170431 columns]

# %% [markdown]
# ## Automated Testing

# %%
try:
    histories
except:
    histories, reports = { }, { }

# %%
possible_heights = list(np.arange(5, step=1)+2) + list(np.arange(10, 50, step=5)) #+ list(np.arange(50, 101, step=10))
possible_num_branches = list(np.arange(4, 11, step=2))
possible_filters = list(np.arange(200, 501, step=100))
possible_dropouts = list(np.arange(.1, .51, step=.1))

# %%
print('possible_heights: {}'.format(possible_heights))
print('possible_num_branches: {}'.format(possible_num_branches))
print('possible_filters: {}'.format(possible_filters))
print('possible_dropouts: {}'.format(possible_dropouts))

# %%
def save_report_histories():
    save_pickle('histories.pkl', reports)
    save_pickle('reports.pkl', reports)

# %%
def load_report_histories():
    return (load_pickle('histories.pkl'),
            load_pickle('reports.pkl'))

# %%
possible_heights = set(possible_heights) #+ list(np.arange(50, 101, step=10)))
possible_num_branches = shuffle(possible_num_branches)
possible_filters = shuffle(possible_filters)
possible_dropouts = shuffle(possible_dropouts)
histories, reports = load_report_histories()
i = 0
for num_branches in possible_num_branches:
    subsets = find_subsets_of_n(possible_heights, num_branches)
    subsets = shuffle(subsets)
    for heights in subsets:
        for filters in possible_filters:
            for dropout_rate in possible_dropouts:
                
                params = (tuple(heights), filters, dropout_rate)
                if params in reports:
                    continue
                print(params)
                kernels = [get_kernel_spec(filters=filters, height=h, width=glove_dim) for h in heights]
                baby = BabyBlueberry.build(kernels=kernels, dropout_rate=dropout_rate)
                adam = tf.keras.optimizers.Adam()
                baby.compile(optimizer=adam, metrics={'stars': star_metrics} ,loss={'stars': BabyBlueberry.loss_fn})
                log_dir = os.path.join(SRC_DIR, 'logs', 'CONV-{}'.format(datetime.fromtimestamp(time.time()).strftime('%H-%M-%S_%m-%d')))
                tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir, write_graph=False, update_freq='batch')
                histories[params] = baby.fit(dataset['train'], steps_per_epoch=100, epochs=5, 
                                             validation_data= dataset['val'], validation_steps=10,
                                             callbacks=[tb], class_weight=class_weights, verbose=1)
                predictions, truth = [], []
                for x, y in dataset['val'].take(100):
                    pred = baby.predict_on_batch(x)
                    truth.append(y['stars'].numpy())
                    predictions.append(tf.argmax(pred['stars'], axis=-1).numpy())
                predictions=np.array(predictions).flatten()
                truth = np.array(truth).flatten()
                reports[params] = classification_report(truth, predictions)
                print(reports[params])
                save_report_histories()

# %%
save_pickle('reports.pkl', reports)
save_pickle('histories.pkl', histories)

# %%
dataset['train'].shuffle

# %%
for x, y in dataset['train']:break
truth = y['stars']
pred = baby(x['review'])['stars']

# %%
print(classification_report(truth, predictions))
