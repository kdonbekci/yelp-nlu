# %%
from packages import *
import tensorflow as tf
from datetime import datetime, timedelta
import time
import pandas as pd
import tensorflow.keras.backend as K
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import *
from sklearn.metrics import classification_report, precision_recall_fscore_support, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import shuffle
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Model
# We will be building our models in this notebook.

# %% [markdown]
# Some configuration required for tensorflow.

# %%
tf.config.gpu.set_per_process_memory_growth(True)
tf.config.gpu.set_per_process_memory_fraction(.25)
tf.keras.backend.set_image_data_format('channels_last')

# %% [markdown]
# ## Dataset

# %%
glove_dim = 50
max_length = 300
chunk_count = 100
random_seed = 100 #np.random.randint(0, 1000000000)
print('using random_seed: {}'.format(random_seed))
splits = ['train', 'val', 'test'] #60:20:20
# Out:
# using random_seed: 100

# %%
tf_text_filenames = [os.path.join(DATASET_DIR, 'preprocessed', 'tfrecord', 'xext',  #xext temporarily
                                  'review-text-{:02d}.tf'.format(i)) for i in range(chunk_count)]
tf_ix_filenames = [os.path.join(DATASET_DIR, 'preprocessed', 'tfrecord', 'ix', 
                                  'review-ix-{:02d}.tf'.format(i)) for i in range(chunk_count)]
all_stars = (load_data({'review': ['stars']})['review']['stars'] - 1).astype(np.int32)# this is so that stars are 0-indexed
N = {}
stars_chunked = all_stars.reshape((chunk_count, 6685900//chunk_count))

class_weights = compute_class_weight('balanced', [0, 1, 2, 3, 4], all_stars)
class_weights = {'five': class_weights, 'ternary': np.array([class_weights[0], class_weights[1:4].sum() , class_weights[4]])}

tf_text, tf_ix, stars= {}, {}, {}

tf_text['train'], tf_text_filenames_val_test, tf_ix['train'], tf_ix_filenames_val_test, stars['train'], stars_val_test \
= train_test_split(tf_text_filenames, tf_ix_filenames, stars_chunked, random_state=random_seed, test_size = .4)

tf_text['val'], tf_text['test'], tf_ix['val'], tf_ix['test'], stars['val'], stars['test'] \
= train_test_split(tf_text_filenames_val_test, tf_ix_filenames_val_test, stars_val_test, random_state=random_seed, test_size = .5)

for split in splits:
    stars[split] = stars[split].reshape(np.product(stars[split].shape))
    N[split] = len(stars[split])

print('({}:{}:{})'.format(len(tf_text['train']), len(tf_text['val']), len(tf_text['test'])))

glove_lookup = load_pickle(os.path.join(GLOVE_DIR, 'glove-{}D-byte-float32.pkl'.format(glove_dim)))
keys_to_ix = load_pickle(os.path.join(GLOVE_DIR, 'glove-byte-keys_to_ix.pkl'))
ix_to_key = {value: key for key, value in keys_to_ix.items()}

unk_vector = np.mean(np.array(list(glove_lookup.values())), axis=0)
null_vector = np.zeros(glove_dim)
glove_lookup[UNK_KEY.encode('ascii')] = unk_vector #if using byte glove dict
glove_lookup[NULL_KEY.encode('ascii')] = null_vector

oops = 0
glove_lookup_array = []
for i in range(len(ix_to_key)):
    if ix_to_key[i] not in glove_lookup:
        oops+=1
    glove_lookup_array.append(glove_lookup.get(ix_to_key[i], null_vector))
glove_lookup_array = np.array(glove_lookup_array, dtype=np.float32)
print('oops {} times.'.format(oops))

@tf.function
def get_review_length(review):
    return tf.cast(tf.reduce_sum(tf.cast(tf.not_equal(review, 0), tf.int8)), tf.int32)

@tf.function
def _parse_function(proto, to_ix):
    # define your tfrecord again. Remember that you saved your image as a string.
    keys_to_features = {'review': tf.io.FixedLenFeature([300,], tf.int64) if to_ix else tf.io.FixedLenFeature([300,], tf.string),}
    
    # Load one example
    parsed_features = tf.io.parse_single_example(proto, keys_to_features)
    
    return parsed_features 

embedding = tf.constant(glove_lookup_array)
@tf.function
def embed(tensor):
    return tf.gather(embedding, tensor)

@tf.function
def add_channel(tensor):
    return tf.expand_dims(tensor, -1)

# 11 GB in memory
# X = []
# x = tf.data.TFRecordDataset(tf_text['train'])
# for y in x :
#     X.append(y)
# Out:
# (60:20:20)
# oops 1 times.

# %%
@tf.function
def get_review_length(review):
    return tf.cast(tf.reduce_sum(tf.cast(tf.not_equal(review, 0), tf.int32)), tf.float32)

# %%
def make_dataset(batch_size, to_embed=False, to_ix=False, channelize=True, to_ternary_task=False, features=None): 
    '''
    Note: once created dataset remains the same from iteration to iteration. 
    In Keras.fit, once given steps_per_epoch the data for epochs are not the same.
    Validation data is the same.
    If cell is rerun, then the same order of data will be fed.
    '''
    if to_ternary_task:
        star_mapping = tf.constant([0, 1, 1, 1, 2], dtype=tf.int32)
    def _prepare_star(star):
        if to_ternary_task: return {'stars': tf.gather(star_mapping, star)}
        return {'stars': star}
    def _parse_transform(x):
        parsed = _parse_function(x, True)['review']
        out = {}
        if features:
            out = {key: f(parsed) for key, f in features.items()}
        if to_ix:
            out['review-ix'] = tf.cast(parsed, tf.int32)
        if to_embed:
            if channelize:
                out['review-embed'] = add_channel(embed(parsed))
            else:
                out['review-embed'] = embed(parsed) 
        return out   
    
    shuffle_buffer_size = batch_size * 100
    prefetch_buffer_size = 4
    files = tf_ix
    dataset = {}
    num_batches = {}
    for split in splits:
        dataset[split] = tf.data.TFRecordDataset(files[split])
        stars_dataset = tf.data.Dataset.from_tensor_slices(stars[split])
        dataset[split] = tf.data.Dataset.zip((dataset[split], stars_dataset))
        dataset[split] = dataset[split].shuffle(shuffle_buffer_size, seed=random_seed)
        dataset[split] = dataset[split].repeat()
        dataset[split] = dataset[split].map(lambda x, y: (_parse_transform(x), _prepare_star(y)), num_parallel_calls=12)
        dataset[split] = dataset[split].batch(batch_size)
        dataset[split] = dataset[split].prefetch(prefetch_buffer_size)
        num_batches[split] = N[split] // batch_size
    print('num_batches: {}, batch_size: {}, shuffle_buffer_size: {}, prefetch_buffer_size: {}'.format(num_batches, batch_size, 
                                                                                 shuffle_buffer_size, prefetch_buffer_size))
    return dataset, num_batches

# %%
# %%time
# for i, (x, y) in enumerate(dataset['train']):
#     if i == 500:
#         break
# for i, (x, y) in enumerate(dataset['train']):
#     if i == 500:
#         break
# # Wall time: 30.1 --> 14.2 --> 4.3 s wow (64 batchsize, glovedim = 300)

# %%
# for x_init, y_init in dataset['train']:break

# %% [markdown]
# # Models

# %% [markdown]
# ### BabyBlueberry
# Convolutional Model with GLoVe embeddings.

# %%
@rename('all_acc')
def all_class_accuracy(y_true, y_pred):
    return tf.keras.metrics.sparse_categorical_accuracy(y_true, y_pred) 

def one_class_recall(label):
    @rename('{}_recalll'.format(label))
    def single_class_recall(y_true, y_pred): # (64, 1), (64, 5) should return (64,)
        truth = K.flatten(K.cast(y_true, 'int32'))
        preds = K.cast(K.argmax(y_pred, axis=-1), 'int32')
        recall_mask = K.cast(K.equal(truth, label), 'int32')        
        recall = K.cast(K.equal(preds, truth), 'int32') * recall_mask
        recall = K.cast(K.sum(recall) / K.maximum(K.sum(recall_mask), 1), 'float32')
        return  K.ones(batch_size, dtype='float32') * recall
    return single_class_recall

def one_class_precision(label):
    @rename('{}_precision'.format(label))
    def single_class_precision(y_true, y_pred): # (64, 1), (64, 5) should return (64,)
        truth = K.flatten(K.cast(y_true, 'int32'))
        preds = K.cast(K.argmax(y_pred, axis=-1), 'int32')
        precision_mask = K.cast(K.equal(preds, label), 'int32')          
        precision = K.cast(K.equal(preds, truth), 'int32') * precision_mask
        precision = K.cast(K.sum(precision) / K.maximum(K.sum(precision_mask), 1), 'float32')
        return  K.ones(batch_size, dtype='float32') * precision
    return single_class_precision

# %%
star_metrics = [all_class_accuracy]
star_metrics += [one_class_recall(i) for i in range(5)] + [one_class_precision(i) for i in range(5)]

# %%
def get_kernel_spec(filters, height, width):
    return {'filters':filters, 'height': height, 'width': width}

# %%
class BabyBerry:
    
    def build(dropout_rate, kernels, out_units, input_shape=(max_length, glove_dim, 1)):
        ix_input = Input(shape= (max_length,), name='review-ix')
        glove_input = Input(shape=input_shape, name='review-embed')
        length_input = Input(shape=(1,), name='review-length')
        embedding = Embedding(input_dim=len(glove_lookup_array), output_dim=glove_dim, 
                              input_length=max_length, name='trained_embed')(ix_input)
        
        channel_embedding = Reshape(target_shape=(max_length, glove_dim, 1), name='reshape_embed')(embedding)
                
        combined_embedding = Concatenate(name='concat_embed')([channel_embedding, glove_input])
        branches = []
        names = {}
        for kernel in kernels:
            if (kernel['height'], kernel['width']) in names:
                names[(kernel['height'], kernel['width'])] = i = names[(kernel['height'], kernel['width'])] + 1
            else:
                names[(kernel['height'], kernel['width'])] = i = 1
            branch = Conv2D(kernel['filters'], (kernel['height'], kernel['width']), activation='relu', 
                            name='conv_{}_{}_{}'.format(kernel['height'], kernel['width'], i), 
                            padding='valid')(combined_embedding)
            branch = GlobalMaxPool2D(name='pool_{}_{}_{}'.format(kernel['height'], kernel['width'], i))(branch)
            branches.append(branch)
        
        
        x = Concatenate(name='concat_conv')(branches + [length_input])
        x = Dropout(rate=dropout_rate, name='dropout_1')(x)
        x = Dense(100, activation='relu', name='dense_1')(x)
        out = Dense(out_units, activation='softmax', name='stars')(x)
        
        return tf.keras.models.Model(inputs={'review-embed':glove_input, 'review-ix': ix_input, 'review-length':length_input}, 
                                     outputs={'stars': out}, name='BabyBerry')
        
    @tf.function
    def loss_fn(truth, logits):
        loss = tf.keras.losses.sparse_categorical_crossentropy(truth, logits)
        return loss

# %%
batch_size = 256
dataset, num_batches = make_dataset(batch_size=batch_size, to_embed=True, to_ix=True, channelize=True, 
                                    features={'review-length':get_review_length})
# Out:
# num_batches: {'train': 15670, 'val': 5223, 'test': 5223}, batch_size: 256, shuffle_buffer_size: 25600, prefetch_buffer_size: 4

# %%
kernels = [get_kernel_spec(filters=100, height=h, width=glove_dim) for h in [2, 3, 4, 5, 10]]
baby = BabyBerry.build(kernels=kernels, dropout_rate=.1, out_units=5)
adam = tf.keras.optimizers.Adam()
baby.compile(optimizer=adam, metrics={'stars': star_metrics} ,loss={'stars': BabyBerry.loss_fn})

# %%
log_dir = os.path.join(SRC_DIR, 'logs', '{}-CONV-BabyBerry'.format(datetime.fromtimestamp(time.time()).strftime('%d-%m_%H-%M-%S')))
tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir, write_graph=False, update_freq='batch')

# %%
_=baby.fit(dataset['train'], steps_per_epoch=100, epochs=150, 
                             validation_data= dataset['val'], validation_steps=20,
                             callbacks=[tb], class_weight=class_weights['five'], verbose=1, shuffle=False)
# Out:
# Epoch 1/150
# 100/100 [==============================] - 42s 422ms/step - loss: 1.3446 - all_acc: 0.4849 - 0_recalll: 0.3913 - 1_recalll: 0.0258 - 2_recalll: 0.0779 - 3_recalll: 0.2279 - 4_recalll: 0.8391 - 0_precision: 0.4637 - 1_precision: 0.0619 - 2_precision: 0.1639 - 3_precision: 0.3033 - 4_precision: 0.5529 - val_loss: 0.9883 - val_all_acc: 0.5869 - val_0_recalll: 0.6589 - val_1_recalll: 0.2918 - val_2_recalll: 0.0275 - val_3_recalll: 0.2467 - val_4_recalll: 0.9251 - val_0_precision: 0.6792 - val_1_precision: 0.3133 - val_2_precision: 0.3792 - val_3_precision: 0.3705 - val_4_precision: 0.6523
# Epoch 2/150
# 100/100 [==============================] - 39s 391ms/step - loss: 0.9088 - all_acc: 0.6162 - 0_recalll: 0.7776 - 1_recalll: 0.1558 - 2_recalll: 0.2609 - 3_recalll: 0.4048 - 4_recalll: 0.8504 - 0_precision: 0.6582 - 1_precision: 0.2921 - 2_precision: 0.3604 - 3_precision: 0.4725 - 4_precision: 0.7322 - val_loss: 0.8255 - val_all_acc: 0.6553 - val_0_recalll: 0.8436 - val_1_recalll: 0.3737 - val_2_recalll: 0.2125 - val_3_recalll: 0.3726 - val_4_recalll: 0.8991 - val_0_precision: 0.6614 - val_1_precision: 0.3761 - val_2_precision: 0.4949 - val_3_precision: 0.5140 - val_4_precision: 0.7525
# Epoch 3/150
# 100/100 [==============================] - 42s 423ms/step - loss: 0.8292 - all_acc: 0.6489 - 0_recalll: 0.8092 - 1_recalll: 0.2053 - 2_recalll: 0.3682 - 3_recalll: 0.4527 - 4_recalll: 0.8562 - 0_precision: 0.6929 - 1_precision: 0.3907 - 2_precision: 0.4559 - 3_precision: 0.5147 - 4_precision: 0.7666 - val_loss: 0.7824 - val_all_acc: 0.6689 - val_0_recalll: 0.8680 - val_1_recalll: 0.1502 - val_2_recalll: 0.3468 - val_3_recalll: 0.5020 - val_4_recalll: 0.8678 - val_0_precision: 0.6862 - val_1_precision: 0.5181 - val_2_precision: 0.4871 - val_3_precision: 0.4859 - val_4_precision: 0.7874
# Epoch 4/150
# 100/100 [==============================] - 39s 391ms/step - loss: 0.8044 - all_acc: 0.6580 - 0_recalll: 0.8320 - 1_recalll: 0.2361 - 2_recalll: 0.3825 - 3_recalll: 0.4624 - 4_recalll: 0.8537 - 0_precision: 0.7155 - 1_precision: 0.4223 - 2_precision: 0.4679 - 3_precision: 0.5177 - 4_precision: 0.7748 - val_loss: 0.8014 - val_all_acc: 0.6564 - val_0_recalll: 0.9063 - val_1_recalll: 0.1270 - val_2_recalll: 0.5588 - val_3_recalll: 0.1768 - val_4_recalll: 0.9280 - val_0_precision: 0.6521 - val_1_precision: 0.4522 - val_2_precision: 0.4289 - val_3_precision: 0.5451 - val_4_precision: 0.7409
# Epoch 5/150
# 100/100 [==============================] - 39s 386ms/step - loss: 0.8007 - all_acc: 0.6563 - 0_recalll: 0.8204 - 1_recalll: 0.2672 - 2_recalll: 0.3872 - 3_recalll: 0.4526 - 4_recalll: 0.8538 - 0_precision: 0.7143 - 1_precision: 0.4293 - 2_precision: 0.4841 - 3_precision: 0.5276 - 4_precision: 0.7692 - val_loss: 0.7762 - val_all_acc: 0.6682 - val_0_recalll: 0.7590 - val_1_recalll: 0.6582 - val_2_recalll: 0.2412 - val_3_recalll: 0.5183 - val_4_recalll: 0.8255 - val_0_precision: 0.7879 - val_1_precision: 0.3733 - val_2_precision: 0.5518 - val_3_precision: 0.5116 - val_4_precision: 0.8189
# Epoch 6/150
# 100/100 [==============================] - 41s 414ms/step - loss: 0.7707 - all_acc: 0.6679 - 0_recalll: 0.8245 - 1_recalll: 0.3064 - 2_recalll: 0.3981 - 3_recalll: 0.4709 - 4_recalll: 0.8580 - 0_precision: 0.7389 - 1_precision: 0.4765 - 2_precision: 0.4775 - 3_precision: 0.5364 - 4_precision: 0.7786 - val_loss: 0.7434 - val_all_acc: 0.6848 - val_0_recalll: 0.8803 - val_1_recalll: 0.3519 - val_2_recalll: 0.4520 - val_3_recalll: 0.3423 - val_4_recalll: 0.9104 - val_0_precision: 0.7160 - val_1_precision: 0.4908 - val_2_precision: 0.5199 - val_3_precision: 0.5532 - val_4_precision: 0.7629
# Epoch 7/150
# 100/100 [==============================] - 41s 409ms/step - loss: 0.7898 - all_acc: 0.6612 - 0_recalll: 0.8180 - 1_recalll: 0.3295 - 2_recalll: 0.3881 - 3_recalll: 0.4738 - 4_recalll: 0.8507 - 0_precision: 0.7312 - 1_precision: 0.4850 - 2_precision: 0.4685 - 3_precision: 0.5295 - 4_precision: 0.7806 - val_loss: 0.7380 - val_all_acc: 0.6840 - val_0_recalll: 0.8040 - val_1_recalll: 0.4413 - val_2_recalll: 0.2977 - val_3_recalll: 0.4575 - val_4_recalll: 0.9006 - val_0_precision: 0.7741 - val_1_precision: 0.4491 - val_2_precision: 0.5766 - val_3_precision: 0.5179 - val_4_precision: 0.7703
# Epoch 8/150
# 100/100 [==============================] - 39s 389ms/step - loss: 0.7532 - all_acc: 0.6777 - 0_recalll: 0.8403 - 1_recalll: 0.3017 - 2_recalll: 0.4271 - 3_recalll: 0.4679 - 4_recalll: 0.8670 - 0_precision: 0.7309 - 1_precision: 0.4865 - 2_precision: 0.4966 - 3_precision: 0.5439 - 4_precision: 0.7844 - val_loss: 0.7366 - val_all_acc: 0.6816 - val_0_recalll: 0.8314 - val_1_recalll: 0.4643 - val_2_recalll: 0.3897 - val_3_recalll: 0.6086 - val_4_recalll: 0.7885 - val_0_precision: 0.7671 - val_1_precision: 0.4606 - val_2_precision: 0.5482 - val_3_precision: 0.4977 - val_4_precision: 0.8409
# Epoch 9/150
# 100/100 [==============================] - 40s 400ms/step - loss: 0.7519 - all_acc: 0.6829 - 0_recalll: 0.8303 - 1_recalll: 0.3671 - 2_recalll: 0.4262 - 3_recalll: 0.4763 - 4_recalll: 0.8666 - 0_precision: 0.7553 - 1_precision: 0.4988 - 2_precision: 0.5065 - 3_precision: 0.5587 - 4_precision: 0.7841 - val_loss: 0.7313 - val_all_acc: 0.6877 - val_0_recalll: 0.8706 - val_1_recalll: 0.2627 - val_2_recalll: 0.5711 - val_3_recalll: 0.2772 - val_4_recalll: 0.9348 - val_0_precision: 0.7516 - val_1_precision: 0.4977 - val_2_precision: 0.4669 - val_3_precision: 0.5966 - val_4_precision: 0.7561
# Epoch 10/150
# 100/100 [==============================] - 42s 421ms/step - loss: 0.7478 - all_acc: 0.6840 - 0_recalll: 0.8399 - 1_recalll: 0.3072 - 2_recalll: 0.4248 - 3_recalll: 0.4565 - 4_recalll: 0.8758 - 0_precision: 0.7414 - 1_precision: 0.4983 - 2_precision: 0.5059 - 3_precision: 0.5434 - 4_precision: 0.7912 - val_loss: 0.7277 - val_all_acc: 0.6939 - val_0_recalll: 0.7847 - val_1_recalll: 0.3678 - val_2_recalll: 0.4778 - val_3_recalll: 0.5546 - val_4_recalll: 0.8501 - val_0_precision: 0.8240 - val_1_precision: 0.5079 - val_2_precision: 0.5218 - val_3_precision: 0.5150 - val_4_precision: 0.8126
# Epoch 11/150
# 100/100 [==============================] - 39s 392ms/step - loss: 0.7468 - all_acc: 0.6776 - 0_recalll: 0.8326 - 1_recalll: 0.3296 - 2_recalll: 0.4360 - 3_recalll: 0.4825 - 4_recalll: 0.8595 - 0_precision: 0.7405 - 1_precision: 0.4781 - 2_precision: 0.5113 - 3_precision: 0.5511 - 4_precision: 0.7805 - val_loss: 0.7198 - val_all_acc: 0.6877 - val_0_recalll: 0.8665 - val_1_recalll: 0.3311 - val_2_recalll: 0.4612 - val_3_recalll: 0.5929 - val_4_recalll: 0.8045 - val_0_precision: 0.7659 - val_1_precision: 0.5026 - val_2_precision: 0.5148 - val_3_precision: 0.5017 - val_4_precision: 0.8379
# Epoch 12/150
# 100/100 [==============================] - 39s 386ms/step - loss: 0.7434 - all_acc: 0.6830 - 0_recalll: 0.8470 - 1_recalll: 0.3213 - 2_recalll: 0.4532 - 3_recalll: 0.4796 - 4_recalll: 0.8611 - 0_precision: 0.7472 - 1_precision: 0.5090 - 2_precision: 0.5206 - 3_precision: 0.5479 - 4_precision: 0.7860 - val_loss: 0.7306 - val_all_acc: 0.6891 - val_0_recalll: 0.7987 - val_1_recalll: 0.5577 - val_2_recalll: 0.2037 - val_3_recalll: 0.4143 - val_4_recalll: 0.9368 - val_0_precision: 0.8027 - val_1_precision: 0.4414 - val_2_precision: 0.6606 - val_3_precision: 0.5356 - val_4_precision: 0.7571
# Epoch 13/150
# 100/100 [==============================] - 42s 424ms/step - loss: 0.7235 - all_acc: 0.6921 - 0_recalll: 0.8503 - 1_recalll: 0.3488 - 2_recalll: 0.4370 - 3_recalll: 0.4800 - 4_recalll: 0.8692 - 0_precision: 0.7627 - 1_precision: 0.4963 - 2_precision: 0.5254 - 3_precision: 0.5531 - 4_precision: 0.7884 - val_loss: 0.7442 - val_all_acc: 0.6855 - val_0_recalll: 0.9449 - val_1_recalll: 0.0841 - val_2_recalll: 0.5005 - val_3_recalll: 0.6001 - val_4_recalll: 0.8068 - val_0_precision: 0.6446 - val_1_precision: 0.5474 - val_2_precision: 0.5388 - val_3_precision: 0.5186 - val_4_precision: 0.8461
# Epoch 14/150
# 100/100 [==============================] - 40s 403ms/step - loss: 0.7013 - all_acc: 0.7055 - 0_recalll: 0.8597 - 1_recalll: 0.3431 - 2_recalll: 0.4292 - 3_recalll: 0.4718 - 4_recalll: 0.8809 - 0_precision: 0.7713 - 1_precision: 0.5067 - 2_precision: 0.5158 - 3_precision: 0.5597 - 4_precision: 0.8002 - val_loss: 0.7045 - val_all_acc: 0.7047 - val_0_recalll: 0.8207 - val_1_recalll: 0.4616 - val_2_recalll: 0.4126 - val_3_recalll: 0.5578 - val_4_recalll: 0.8602 - val_0_precision: 0.7884 - val_1_precision: 0.4716 - val_2_precision: 0.5460 - val_3_precision: 0.5471 - val_4_precision: 0.8268
# Epoch 15/150
# 100/100 [==============================] - 39s 387ms/step - loss: 0.6916 - all_acc: 0.7091 - 0_recalll: 0.8638 - 1_recalll: 0.3468 - 2_recalll: 0.4245 - 3_recalll: 0.4850 - 4_recalll: 0.8799 - 0_precision: 0.7758 - 1_precision: 0.4952 - 2_precision: 0.5217 - 3_precision: 0.5626 - 4_precision: 0.8017 - val_loss: 0.6986 - val_all_acc: 0.7053 - val_0_recalll: 0.8979 - val_1_recalll: 0.3547 - val_2_recalll: 0.3955 - val_3_recalll: 0.5002 - val_4_recalll: 0.8903 - val_0_precision: 0.7350 - val_1_precision: 0.4871 - val_2_precision: 0.5644 - val_3_precision: 0.5604 - val_4_precision: 0.8032
# Epoch 16/150
# 100/100 [==============================] - 40s 404ms/step - loss: 0.7160 - all_acc: 0.6975 - 0_recalll: 0.8559 - 1_recalll: 0.3489 - 2_recalll: 0.4379 - 3_recalll: 0.4751 - 4_recalll: 0.8765 - 0_precision: 0.7647 - 1_precision: 0.5136 - 2_precision: 0.5149 - 3_precision: 0.5561 - 4_precision: 0.7961 - val_loss: 0.6999 - val_all_acc: 0.6980 - val_0_recalll: 0.8378 - val_1_recalll: 0.4152 - val_2_recalll: 0.5078 - val_3_recalll: 0.3528 - val_4_recalll: 0.9217 - val_0_precision: 0.7787 - val_1_precision: 0.4876 - val_2_precision: 0.5205 - val_3_precision: 0.5725 - val_4_precision: 0.7729
# Epoch 17/150
# 100/100 [==============================] - 42s 422ms/step - loss: 0.7305 - all_acc: 0.6887 - 0_recalll: 0.8377 - 1_recalll: 0.3534 - 2_recalll: 0.4393 - 3_recalll: 0.4866 - 4_recalll: 0.8648 - 0_precision: 0.7580 - 1_precision: 0.4795 - 2_precision: 0.5346 - 3_precision: 0.5555 - 4_precision: 0.7915 - val_loss: 0.7102 - val_all_acc: 0.6941 - val_0_recalll: 0.9007 - val_1_recalll: 0.2592 - val_2_recalll: 0.4529 - val_3_recalll: 0.3443 - val_4_recalll: 0.9402 - val_0_precision: 0.7033 - val_1_precision: 0.4897 - val_2_precision: 0.5522 - val_3_precision: 0.5851 - val_4_precision: 0.7561
# Epoch 18/150
# 100/100 [==============================] - 39s 386ms/step - loss: 0.7255 - all_acc: 0.6908 - 0_recalll: 0.8430 - 1_recalll: 0.3574 - 2_recalll: 0.4641 - 3_recalll: 0.4588 - 4_recalll: 0.8734 - 0_precision: 0.7604 - 1_precision: 0.5025 - 2_precision: 0.5229 - 3_precision: 0.5594 - 4_precision: 0.7851 - val_loss: 0.6987 - val_all_acc: 0.7055 - val_0_recalll: 0.8309 - val_1_recalll: 0.4755 - val_2_recalll: 0.4168 - val_3_recalll: 0.6163 - val_4_recalll: 0.8287 - val_0_precision: 0.7840 - val_1_precision: 0.4774 - val_2_precision: 0.5809 - val_3_precision: 0.5349 - val_4_precision: 0.8445
# Epoch 19/150
# 100/100 [==============================] - 39s 392ms/step - loss: 0.7159 - all_acc: 0.6969 - 0_recalll: 0.8442 - 1_recalll: 0.3708 - 2_recalll: 0.4524 - 3_recalll: 0.4902 - 4_recalll: 0.8731 - 0_precision: 0.7626 - 1_precision: 0.5182 - 2_precision: 0.5287 - 3_precision: 0.5718 - 4_precision: 0.7951 - val_loss: 0.7032 - val_all_acc: 0.6996 - val_0_recalll: 0.8540 - val_1_recalll: 0.4864 - val_2_recalll: 0.3247 - val_3_recalll: 0.4021 - val_4_recalll: 0.9329 - val_0_precision: 0.7798 - val_1_precision: 0.4894 - val_2_precision: 0.6190 - val_3_precision: 0.5556 - val_4_precision: 0.7610
# Epoch 20/150
# 100/100 [==============================] - 42s 423ms/step - loss: 0.7141 - all_acc: 0.6972 - 0_recalll: 0.8507 - 1_recalll: 0.3541 - 2_recalll: 0.4649 - 3_recalll: 0.4654 - 4_recalll: 0.8768 - 0_precision: 0.7589 - 1_precision: 0.4972 - 2_precision: 0.5475 - 3_precision: 0.5487 - 4_precision: 0.7975 - val_loss: 0.6954 - val_all_acc: 0.7094 - val_0_recalll: 0.7977 - val_1_recalll: 0.3756 - val_2_recalll: 0.5144 - val_3_recalll: 0.5195 - val_4_recalll: 0.8860 - val_0_precision: 0.8173 - val_1_precision: 0.5233 - val_2_precision: 0.5471 - val_3_precision: 0.5625 - val_4_precision: 0.7983
# Epoch 21/150
# 100/100 [==============================] - 40s 403ms/step - loss: 0.7090 - all_acc: 0.7010 - 0_recalll: 0.8501 - 1_recalll: 0.3957 - 2_recalll: 0.4552 - 3_recalll: 0.5002 - 4_recalll: 0.8700 - 0_precision: 0.7715 - 1_precision: 0.5214 - 2_precision: 0.5435 - 3_precision: 0.5751 - 4_precision: 0.7978 - val_loss: 0.6916 - val_all_acc: 0.7039 - val_0_recalll: 0.7654 - val_1_recalll: 0.5761 - val_2_recalll: 0.4502 - val_3_recalll: 0.4529 - val_4_recalll: 0.8940 - val_0_precision: 0.8197 - val_1_precision: 0.4529 - val_2_precision: 0.5439 - val_3_precision: 0.5861 - val_4_precision: 0.7983
# Epoch 22/150
# 100/100 [==============================] - 39s 390ms/step - loss: 0.7106 - all_acc: 0.6964 - 0_recalll: 0.8468 - 1_recalll: 0.3591 - 2_recalll: 0.4510 - 3_recalll: 0.4929 - 4_recalll: 0.8743 - 0_precision: 0.7670 - 1_precision: 0.5039 - 2_precision: 0.5318 - 3_precision: 0.5737 - 4_precision: 0.7935 - val_loss: 0.6885 - val_all_acc: 0.7051 - val_0_recalll: 0.8460 - val_1_recalll: 0.3446 - val_2_recalll: 0.6299 - val_3_recalll: 0.4100 - val_4_recalll: 0.8893 - val_0_precision: 0.7919 - val_1_precision: 0.5451 - val_2_precision: 0.4735 - val_3_precision: 0.5911 - val_4_precision: 0.8057
# Epoch 23/150
# 100/100 [==============================] - 41s 409ms/step - loss: 0.7091 - all_acc: 0.6979 - 0_recalll: 0.8514 - 1_recalll: 0.3667 - 2_recalll: 0.4332 - 3_recalll: 0.4772 - 4_recalll: 0.8764 - 0_precision: 0.7671 - 1_precision: 0.4921 - 2_precision: 0.5180 - 3_precision: 0.5649 - 4_precision: 0.7966 - val_loss: 0.7009 - val_all_acc: 0.6979 - val_0_recalll: 0.8029 - val_1_recalll: 0.5207 - val_2_recalll: 0.2759 - val_3_recalll: 0.6380 - val_4_recalll: 0.8383 - val_0_precision: 0.8148 - val_1_precision: 0.4811 - val_2_precision: 0.6082 - val_3_precision: 0.5054 - val_4_precision: 0.8337
# Epoch 24/150
# 100/100 [==============================] - 42s 417ms/step - loss: 0.7011 - all_acc: 0.7042 - 0_recalll: 0.8563 - 1_recalll: 0.3583 - 2_recalll: 0.4577 - 3_recalll: 0.4949 - 4_recalll: 0.8783 - 0_precision: 0.7629 - 1_precision: 0.4945 - 2_precision: 0.5304 - 3_precision: 0.5828 - 4_precision: 0.8010 - val_loss: 0.6891 - val_all_acc: 0.7023 - val_0_recalll: 0.8460 - val_1_recalll: 0.4806 - val_2_recalll: 0.5025 - val_3_recalll: 0.4513 - val_4_recalll: 0.8721 - val_0_precision: 0.7570 - val_1_precision: 0.4772 - val_2_precision: 0.5098 - val_3_precision: 0.5708 - val_4_precision: 0.8202
# Epoch 25/150
# 100/100 [==============================] - 39s 391ms/step - loss: 0.6962 - all_acc: 0.7033 - 0_recalll: 0.8506 - 1_recalll: 0.3645 - 2_recalll: 0.4338 - 3_recalll: 0.5112 - 4_recalll: 0.8741 - 0_precision: 0.7631 - 1_precision: 0.4962 - 2_precision: 0.5205 - 3_precision: 0.5778 - 4_precision: 0.7996 - val_loss: 0.6842 - val_all_acc: 0.7057 - val_0_recalll: 0.9077 - val_1_recalll: 0.2543 - val_2_recalll: 0.5255 - val_3_recalll: 0.4480 - val_4_recalll: 0.8989 - val_0_precision: 0.7112 - val_1_precision: 0.5732 - val_2_precision: 0.5479 - val_3_precision: 0.5773 - val_4_precision: 0.7931
# Epoch 26/150
# 100/100 [==============================] - 39s 394ms/step - loss: 0.7049 - all_acc: 0.7023 - 0_recalll: 0.8588 - 1_recalll: 0.3774 - 2_recalll: 0.4460 - 3_recalll: 0.4922 - 4_recalll: 0.8741 - 0_precision: 0.7639 - 1_precision: 0.5188 - 2_precision: 0.5172 - 3_precision: 0.5748 - 4_precision: 0.7999 - val_loss: 0.6808 - val_all_acc: 0.7090 - val_0_recalll: 0.8966 - val_1_recalll: 0.3647 - val_2_recalll: 0.3937 - val_3_recalll: 0.4699 - val_4_recalll: 0.9123 - val_0_precision: 0.7245 - val_1_precision: 0.5130 - val_2_precision: 0.5730 - val_3_precision: 0.5725 - val_4_precision: 0.7949
# Epoch 27/150
# 100/100 [==============================] - 42s 424ms/step - loss: 0.7011 - all_acc: 0.7030 - 0_recalll: 0.8625 - 1_recalll: 0.3651 - 2_recalll: 0.4393 - 3_recalll: 0.4857 - 4_recalll: 0.8751 - 0_precision: 0.7781 - 1_precision: 0.4994 - 2_precision: 0.5274 - 3_precision: 0.5671 - 4_precision: 0.7982 - val_loss: 0.7005 - val_all_acc: 0.6982 - val_0_recalll: 0.7864 - val_1_recalll: 0.3723 - val_2_recalll: 0.6521 - val_3_recalll: 0.4949 - val_4_recalll: 0.8406 - val_0_precision: 0.8043 - val_1_precision: 0.4822 - val_2_precision: 0.4744 - val_3_precision: 0.5598 - val_4_precision: 0.8395
# Epoch 28/150
# 100/100 [==============================] - 40s 396ms/step - loss: 0.6945 - all_acc: 0.7075 - 0_recalll: 0.8755 - 1_recalll: 0.3544 - 2_recalll: 0.4563 - 3_recalll: 0.4712 - 4_recalll: 0.8787 - 0_precision: 0.7843 - 1_precision: 0.5078 - 2_precision: 0.5319 - 3_precision: 0.5654 - 4_precision: 0.7968 - val_loss: 0.7006 - val_all_acc: 0.6994 - val_0_recalll: 0.8164 - val_1_recalll: 0.5571 - val_2_recalll: 0.2333 - val_3_recalll: 0.4874 - val_4_recalll: 0.9116 - val_0_precision: 0.7833 - val_1_precision: 0.4279 - val_2_precision: 0.5988 - val_3_precision: 0.5541 - val_4_precision: 0.7940
# Epoch 29/150
# 100/100 [==============================] - 39s 392ms/step - loss: 0.6947 - all_acc: 0.7077 - 0_recalll: 0.8598 - 1_recalll: 0.3717 - 2_recalll: 0.4405 - 3_recalll: 0.5101 - 4_recalll: 0.8747 - 0_precision: 0.7717 - 1_precision: 0.5189 - 2_precision: 0.5343 - 3_precision: 0.5821 - 4_precision: 0.8037 - val_loss: 0.7083 - val_all_acc: 0.6939 - val_0_recalll: 0.7518 - val_1_recalll: 0.6260 - val_2_recalll: 0.2793 - val_3_recalll: 0.4331 - val_4_recalll: 0.9204 - val_0_precision: 0.8540 - val_1_precision: 0.4630 - val_2_precision: 0.6319 - val_3_precision: 0.5339 - val_4_precision: 0.7644
# Epoch 30/150
# 100/100 [==============================] - 42s 417ms/step - loss: 0.7044 - all_acc: 0.7002 - 0_recalll: 0.8362 - 1_recalll: 0.3780 - 2_recalll: 0.4648 - 3_recalll: 0.4864 - 4_recalll: 0.8754 - 0_precision: 0.7570 - 1_precision: 0.5048 - 2_precision: 0.5418 - 3_precision: 0.5727 - 4_precision: 0.7995 - val_loss: 0.6878 - val_all_acc: 0.7035 - val_0_recalll: 0.8448 - val_1_recalll: 0.5310 - val_2_recalll: 0.3168 - val_3_recalll: 0.5636 - val_4_recalll: 0.8605 - val_0_precision: 0.7724 - val_1_precision: 0.4491 - val_2_precision: 0.6068 - val_3_precision: 0.5474 - val_4_precision: 0.8233
# Epoch 31/150
# 100/100 [==============================] - 41s 408ms/step - loss: 0.7089 - all_acc: 0.7012 - 0_recalll: 0.8517 - 1_recalll: 0.3806 - 2_recalll: 0.4543 - 3_recalll: 0.4902 - 4_recalll: 0.8738 - 0_precision: 0.7728 - 1_precision: 0.5017 - 2_precision: 0.5371 - 3_precision: 0.5769 - 4_precision: 0.7931 - val_loss: 0.6851 - val_all_acc: 0.7064 - val_0_recalll: 0.8571 - val_1_recalll: 0.4748 - val_2_recalll: 0.5070 - val_3_recalll: 0.5079 - val_4_recalll: 0.8526 - val_0_precision: 0.7663 - val_1_precision: 0.5241 - val_2_precision: 0.5276 - val_3_precision: 0.5503 - val_4_precision: 0.8296
# Epoch 32/150
# 100/100 [==============================] - 39s 390ms/step - loss: 0.7201 - all_acc: 0.6946 - 0_recalll: 0.8443 - 1_recalll: 0.3787 - 2_recalll: 0.4439 - 3_recalll: 0.4933 - 4_recalll: 0.8691 - 0_precision: 0.7656 - 1_precision: 0.4845 - 2_precision: 0.5176 - 3_precision: 0.5657 - 4_precision: 0.7926 - val_loss: 0.6924 - val_all_acc: 0.7018 - val_0_recalll: 0.7242 - val_1_recalll: 0.6449 - val_2_recalll: 0.4001 - val_3_recalll: 0.4355 - val_4_recalll: 0.9102 - val_0_precision: 0.8540 - val_1_precision: 0.4439 - val_2_precision: 0.5811 - val_3_precision: 0.5771 - val_4_precision: 0.7849
# Epoch 33/150
# 100/100 [==============================] - 40s 402ms/step - loss: 0.6772 - all_acc: 0.7140 - 0_recalll: 0.8705 - 1_recalll: 0.3729 - 2_recalll: 0.4417 - 3_recalll: 0.4991 - 4_recalll: 0.8819 - 0_precision: 0.7858 - 1_precision: 0.4983 - 2_precision: 0.5310 - 3_precision: 0.5846 - 4_precision: 0.8045 - val_loss: 0.7070 - val_all_acc: 0.6928 - val_0_recalll: 0.8899 - val_1_recalll: 0.4057 - val_2_recalll: 0.2971 - val_3_recalll: 0.6679 - val_4_recalll: 0.7999 - val_0_precision: 0.7370 - val_1_precision: 0.5061 - val_2_precision: 0.6406 - val_3_precision: 0.4913 - val_4_precision: 0.8523
# Epoch 34/150
# 100/100 [==============================] - 42s 422ms/step - loss: 0.6815 - all_acc: 0.7094 - 0_recalll: 0.8617 - 1_recalll: 0.3548 - 2_recalll: 0.4614 - 3_recalll: 0.4995 - 4_recalll: 0.8762 - 0_precision: 0.7721 - 1_precision: 0.4826 - 2_precision: 0.5380 - 3_precision: 0.5818 - 4_precision: 0.8058 - val_loss: 0.7100 - val_all_acc: 0.7045 - val_0_recalll: 0.7785 - val_1_recalll: 0.5878 - val_2_recalll: 0.2631 - val_3_recalll: 0.4695 - val_4_recalll: 0.9313 - val_0_precision: 0.8470 - val_1_precision: 0.4992 - val_2_precision: 0.6386 - val_3_precision: 0.5360 - val_4_precision: 0.7728
# Epoch 35/150
# 100/100 [==============================] - 39s 393ms/step - loss: 0.6918 - all_acc: 0.7066 - 0_recalll: 0.8509 - 1_recalll: 0.3767 - 2_recalll: 0.4722 - 3_recalll: 0.5030 - 4_recalll: 0.8754 - 0_precision: 0.7702 - 1_precision: 0.4978 - 2_precision: 0.5420 - 3_precision: 0.5831 - 4_precision: 0.8032 - val_loss: 0.6843 - val_all_acc: 0.7068 - val_0_recalll: 0.8618 - val_1_recalll: 0.3710 - val_2_recalll: 0.4699 - val_3_recalll: 0.6480 - val_4_recalll: 0.8115 - val_0_precision: 0.7734 - val_1_precision: 0.5380 - val_2_precision: 0.5717 - val_3_precision: 0.5237 - val_4_precision: 0.8531
# Epoch 36/150
# 100/100 [==============================] - 39s 394ms/step - loss: 0.6983 - all_acc: 0.7022 - 0_recalll: 0.8509 - 1_recalll: 0.3705 - 2_recalll: 0.4548 - 3_recalll: 0.4915 - 4_recalll: 0.8760 - 0_precision: 0.7624 - 1_precision: 0.5212 - 2_precision: 0.5226 - 3_precision: 0.5698 - 4_precision: 0.7997 - val_loss: 0.6810 - val_all_acc: 0.7063 - val_0_recalll: 0.8826 - val_1_recalll: 0.3784 - val_2_recalll: 0.5407 - val_3_recalll: 0.3616 - val_4_recalll: 0.9206 - val_0_precision: 0.7744 - val_1_precision: 0.5460 - val_2_precision: 0.5351 - val_3_precision: 0.5803 - val_4_precision: 0.7752
# Epoch 37/150
# 100/100 [==============================] - 42s 417ms/step - loss: 0.6847 - all_acc: 0.7130 - 0_recalll: 0.8638 - 1_recalll: 0.3780 - 2_recalll: 0.4640 - 3_recalll: 0.4917 - 4_recalll: 0.8814 - 0_precision: 0.7762 - 1_precision: 0.5094 - 2_precision: 0.5571 - 3_precision: 0.5793 - 4_precision: 0.8007 - val_loss: 0.6829 - val_all_acc: 0.7061 - val_0_recalll: 0.9131 - val_1_recalll: 0.2788 - val_2_recalll: 0.4308 - val_3_recalll: 0.5646 - val_4_recalll: 0.8611 - val_0_precision: 0.6954 - val_1_precision: 0.5159 - val_2_precision: 0.6037 - val_3_precision: 0.5455 - val_4_precision: 0.8277
# Epoch 38/150
# 100/100 [==============================] - 40s 400ms/step - loss: 0.6727 - all_acc: 0.7177 - 0_recalll: 0.8809 - 1_recalll: 0.3586 - 2_recalll: 0.4413 - 3_recalll: 0.4982 - 4_recalll: 0.8808 - 0_precision: 0.7830 - 1_precision: 0.5010 - 2_precision: 0.5335 - 3_precision: 0.5827 - 4_precision: 0.8082 - val_loss: 0.6789 - val_all_acc: 0.7121 - val_0_recalll: 0.9045 - val_1_recalll: 0.3152 - val_2_recalll: 0.4721 - val_3_recalll: 0.5435 - val_4_recalll: 0.8705 - val_0_precision: 0.7242 - val_1_precision: 0.5633 - val_2_precision: 0.5898 - val_3_precision: 0.5556 - val_4_precision: 0.8196
# Epoch 39/150
# 100/100 [==============================] - 39s 390ms/step - loss: 0.6858 - all_acc: 0.7100 - 0_recalll: 0.8619 - 1_recalll: 0.3664 - 2_recalll: 0.4596 - 3_recalll: 0.4873 - 4_recalll: 0.8810 - 0_precision: 0.7741 - 1_precision: 0.5037 - 2_precision: 0.5440 - 3_precision: 0.5779 - 4_precision: 0.8015 - val_loss: 0.6943 - val_all_acc: 0.6988 - val_0_recalll: 0.7314 - val_1_recalll: 0.6807 - val_2_recalll: 0.3105 - val_3_recalll: 0.4800 - val_4_recalll: 0.8971 - val_0_precision: 0.8482 - val_1_precision: 0.4119 - val_2_precision: 0.6422 - val_3_precision: 0.5629 - val_4_precision: 0.7985
# Epoch 40/150
# 100/100 [==============================] - 41s 408ms/step - loss: 0.6971 - all_acc: 0.7039 - 0_recalll: 0.8443 - 1_recalll: 0.3753 - 2_recalll: 0.4615 - 3_recalll: 0.4979 - 4_recalll: 0.8783 - 0_precision: 0.7569 - 1_precision: 0.5023 - 2_precision: 0.5364 - 3_precision: 0.5798 - 4_precision: 0.8026 - val_loss: 0.6859 - val_all_acc: 0.7082 - val_0_recalll: 0.8543 - val_1_recalll: 0.2937 - val_2_recalll: 0.5310 - val_3_recalll: 0.5971 - val_4_recalll: 0.8393 - val_0_precision: 0.7913 - val_1_precision: 0.5673 - val_2_precision: 0.5251 - val_3_precision: 0.5330 - val_4_precision: 0.8383
# Epoch 41/150
# 100/100 [==============================] - 42s 416ms/step - loss: 0.6964 - all_acc: 0.7043 - 0_recalll: 0.8525 - 1_recalll: 0.3941 - 2_recalll: 0.4350 - 3_recalll: 0.5233 - 4_recalll: 0.8725 - 0_precision: 0.7710 - 1_precision: 0.5271 - 2_precision: 0.5237 - 3_precision: 0.5812 - 4_precision: 0.8018 - val_loss: 0.6689 - val_all_acc: 0.7178 - val_0_recalll: 0.8644 - val_1_recalll: 0.4431 - val_2_recalll: 0.5321 - val_3_recalll: 0.4536 - val_4_recalll: 0.8992 - val_0_precision: 0.7713 - val_1_precision: 0.5418 - val_2_precision: 0.5638 - val_3_precision: 0.5851 - val_4_precision: 0.8074
# Epoch 42/150
# 100/100 [==============================] - 39s 394ms/step - loss: 0.6980 - all_acc: 0.7039 - 0_recalll: 0.8546 - 1_recalll: 0.3662 - 2_recalll: 0.4507 - 3_recalll: 0.4923 - 4_recalll: 0.8830 - 0_precision: 0.7566 - 1_precision: 0.4925 - 2_precision: 0.5305 - 3_precision: 0.5805 - 4_precision: 0.8041 - val_loss: 0.6752 - val_all_acc: 0.7117 - val_0_recalll: 0.8401 - val_1_recalll: 0.5153 - val_2_recalll: 0.3464 - val_3_recalll: 0.5694 - val_4_recalll: 0.8731 - val_0_precision: 0.7881 - val_1_precision: 0.4960 - val_2_precision: 0.6292 - val_3_precision: 0.5406 - val_4_precision: 0.8212
# Epoch 43/150
# 100/100 [==============================] - 40s 397ms/step - loss: 0.6891 - all_acc: 0.7036 - 0_recalll: 0.8455 - 1_recalll: 0.3951 - 2_recalll: 0.4636 - 3_recalll: 0.4855 - 4_recalll: 0.8819 - 0_precision: 0.7520 - 1_precision: 0.5148 - 2_precision: 0.5323 - 3_precision: 0.5711 - 4_precision: 0.8038 - val_loss: 0.6796 - val_all_acc: 0.7121 - val_0_recalll: 0.8431 - val_1_recalll: 0.3520 - val_2_recalll: 0.4852 - val_3_recalll: 0.4994 - val_4_recalll: 0.9000 - val_0_precision: 0.7956 - val_1_precision: 0.5638 - val_2_precision: 0.5725 - val_3_precision: 0.5575 - val_4_precision: 0.7904
# Epoch 44/150
# 100/100 [==============================] - 42s 419ms/step - loss: 0.7022 - all_acc: 0.7011 - 0_recalll: 0.8410 - 1_recalll: 0.3845 - 2_recalll: 0.4635 - 3_recalll: 0.4977 - 4_recalll: 0.8803 - 0_precision: 0.7477 - 1_precision: 0.5234 - 2_precision: 0.5403 - 3_precision: 0.5796 - 4_precision: 0.7973 - val_loss: 0.6860 - val_all_acc: 0.7063 - val_0_recalll: 0.8148 - val_1_recalll: 0.6134 - val_2_recalll: 0.4111 - val_3_recalll: 0.5630 - val_4_recalll: 0.8367 - val_0_precision: 0.8166 - val_1_precision: 0.4554 - val_2_precision: 0.5894 - val_3_precision: 0.5473 - val_4_precision: 0.8352
# Epoch 45/150
# 100/100 [==============================] - 40s 403ms/step - loss: 0.6845 - all_acc: 0.7096 - 0_recalll: 0.8508 - 1_recalll: 0.3899 - 2_recalll: 0.4643 - 3_recalll: 0.5222 - 4_recalll: 0.8779 - 0_precision: 0.7617 - 1_precision: 0.5211 - 2_precision: 0.5582 - 3_precision: 0.5891 - 4_precision: 0.8075 - val_loss: 0.6804 - val_all_acc: 0.7121 - val_0_recalll: 0.8588 - val_1_recalll: 0.3296 - val_2_recalll: 0.5975 - val_3_recalll: 0.4029 - val_4_recalll: 0.9153 - val_0_precision: 0.8057 - val_1_precision: 0.5722 - val_2_precision: 0.5270 - val_3_precision: 0.5901 - val_4_precision: 0.7811
# Epoch 46/150
# 100/100 [==============================] - 39s 389ms/step - loss: 0.6896 - all_acc: 0.7072 - 0_recalll: 0.8425 - 1_recalll: 0.3986 - 2_recalll: 0.4613 - 3_recalll: 0.5030 - 4_recalll: 0.8800 - 0_precision: 0.7550 - 1_precision: 0.5158 - 2_precision: 0.5472 - 3_precision: 0.5826 - 4_precision: 0.8043 - val_loss: 0.6773 - val_all_acc: 0.7146 - val_0_recalll: 0.7952 - val_1_recalll: 0.4715 - val_2_recalll: 0.4550 - val_3_recalll: 0.4837 - val_4_recalll: 0.9120 - val_0_precision: 0.8259 - val_1_precision: 0.5227 - val_2_precision: 0.5725 - val_3_precision: 0.5675 - val_4_precision: 0.7914
# Epoch 47/150
# 100/100 [==============================] - 41s 409ms/step - loss: 0.6790 - all_acc: 0.7109 - 0_recalll: 0.8538 - 1_recalll: 0.4294 - 2_recalll: 0.4567 - 3_recalll: 0.5135 - 4_recalll: 0.8771 - 0_precision: 0.7756 - 1_precision: 0.5369 - 2_precision: 0.5495 - 3_precision: 0.5824 - 4_precision: 0.8067 - val_loss: 0.6763 - val_all_acc: 0.7135 - val_0_recalll: 0.8591 - val_1_recalll: 0.5165 - val_2_recalll: 0.3253 - val_3_recalll: 0.5257 - val_4_recalll: 0.8966 - val_0_precision: 0.7827 - val_1_precision: 0.4770 - val_2_precision: 0.6015 - val_3_precision: 0.5632 - val_4_precision: 0.8125
# Epoch 48/150
# 100/100 [==============================] - 41s 407ms/step - loss: 0.6874 - all_acc: 0.7101 - 0_recalll: 0.8483 - 1_recalll: 0.3644 - 2_recalll: 0.4800 - 3_recalll: 0.5069 - 4_recalll: 0.8817 - 0_precision: 0.7612 - 1_precision: 0.5126 - 2_precision: 0.5563 - 3_precision: 0.5908 - 4_precision: 0.8073 - val_loss: 0.6938 - val_all_acc: 0.7072 - val_0_recalll: 0.7809 - val_1_recalll: 0.5688 - val_2_recalll: 0.4467 - val_3_recalll: 0.6457 - val_4_recalll: 0.8079 - val_0_precision: 0.8358 - val_1_precision: 0.4885 - val_2_precision: 0.5923 - val_3_precision: 0.5283 - val_4_precision: 0.8558
# Epoch 49/150
# 100/100 [==============================] - 39s 390ms/step - loss: 0.6929 - all_acc: 0.7089 - 0_recalll: 0.8551 - 1_recalll: 0.3826 - 2_recalll: 0.4665 - 3_recalll: 0.5184 - 4_recalll: 0.8792 - 0_precision: 0.7722 - 1_precision: 0.5175 - 2_precision: 0.5334 - 3_precision: 0.5955 - 4_precision: 0.8061 - val_loss: 0.6690 - val_all_acc: 0.7139 - val_0_recalll: 0.9066 - val_1_recalll: 0.2737 - val_2_recalll: 0.5200 - val_3_recalll: 0.4765 - val_4_recalll: 0.9015 - val_0_precision: 0.7386 - val_1_precision: 0.5954 - val_2_precision: 0.5417 - val_3_precision: 0.5784 - val_4_precision: 0.8050
# Epoch 50/150
# 100/100 [==============================] - 40s 404ms/step - loss: 0.6977 - all_acc: 0.7013 - 0_recalll: 0.8449 - 1_recalll: 0.3675 - 2_recalll: 0.4619 - 3_recalll: 0.5074 - 4_recalll: 0.8735 - 0_precision: 0.7635 - 1_precision: 0.5119 - 2_precision: 0.5489 - 3_precision: 0.5869 - 4_precision: 0.7958 - val_loss: 0.6711 - val_all_acc: 0.7184 - val_0_recalll: 0.8585 - val_1_recalll: 0.5496 - val_2_recalll: 0.3795 - val_3_recalll: 0.5142 - val_4_recalll: 0.8936 - val_0_precision: 0.7796 - val_1_precision: 0.4999 - val_2_precision: 0.6029 - val_3_precision: 0.5763 - val_4_precision: 0.8158
# Epoch 51/150
# 100/100 [==============================] - 41s 415ms/step - loss: 0.6898 - all_acc: 0.7047 - 0_recalll: 0.8522 - 1_recalll: 0.3923 - 2_recalll: 0.4494 - 3_recalll: 0.5158 - 4_recalll: 0.8732 - 0_precision: 0.7570 - 1_precision: 0.5226 - 2_precision: 0.5319 - 3_precision: 0.5903 - 4_precision: 0.8034 - val_loss: 0.6778 - val_all_acc: 0.7021 - val_0_recalll: 0.8423 - val_1_recalll: 0.4748 - val_2_recalll: 0.4298 - val_3_recalll: 0.3554 - val_4_recalll: 0.9365 - val_0_precision: 0.7774 - val_1_precision: 0.4899 - val_2_precision: 0.5567 - val_3_precision: 0.5823 - val_4_precision: 0.7669
# Epoch 52/150
# 100/100 [==============================] - 40s 399ms/step - loss: 0.6982 - all_acc: 0.7010 - 0_recalll: 0.8484 - 1_recalll: 0.3820 - 2_recalll: 0.4620 - 3_recalll: 0.5058 - 4_recalll: 0.8717 - 0_precision: 0.7633 - 1_precision: 0.5247 - 2_precision: 0.5368 - 3_precision: 0.5838 - 4_precision: 0.7996 - val_loss: 0.6868 - val_all_acc: 0.7090 - val_0_recalll: 0.8534 - val_1_recalll: 0.3667 - val_2_recalll: 0.6760 - val_3_recalll: 0.3920 - val_4_recalll: 0.8875 - val_0_precision: 0.7912 - val_1_precision: 0.5676 - val_2_precision: 0.4671 - val_3_precision: 0.6030 - val_4_precision: 0.8170
# Epoch 53/150
# 100/100 [==============================] - 39s 393ms/step - loss: 0.6854 - all_acc: 0.7096 - 0_recalll: 0.8588 - 1_recalll: 0.4066 - 2_recalll: 0.4768 - 3_recalll: 0.5200 - 4_recalll: 0.8734 - 0_precision: 0.7681 - 1_precision: 0.5406 - 2_precision: 0.5589 - 3_precision: 0.5889 - 4_precision: 0.8017 - val_loss: 0.6788 - val_all_acc: 0.7127 - val_0_recalll: 0.8401 - val_1_recalll: 0.3724 - val_2_recalll: 0.6291 - val_3_recalll: 0.5162 - val_4_recalll: 0.8514 - val_0_precision: 0.8058 - val_1_precision: 0.5829 - val_2_precision: 0.5141 - val_3_precision: 0.5572 - val_4_precision: 0.8322
# Epoch 54/150
# 100/100 [==============================] - 41s 413ms/step - loss: 0.6968 - all_acc: 0.7046 - 0_recalll: 0.8646 - 1_recalll: 0.3592 - 2_recalll: 0.4939 - 3_recalll: 0.5293 - 4_recalll: 0.8650 - 0_precision: 0.7685 - 1_precision: 0.5131 - 2_precision: 0.5498 - 3_precision: 0.5852 - 4_precision: 0.8017 - val_loss: 0.6844 - val_all_acc: 0.7121 - val_0_recalll: 0.7692 - val_1_recalll: 0.6356 - val_2_recalll: 0.4933 - val_3_recalll: 0.4875 - val_4_recalll: 0.8730 - val_0_precision: 0.8366 - val_1_precision: 0.4531 - val_2_precision: 0.5622 - val_3_precision: 0.5819 - val_4_precision: 0.8263
# Epoch 55/150
# 100/100 [==============================] - 40s 404ms/step - loss: 0.6921 - all_acc: 0.7066 - 0_recalll: 0.8571 - 1_recalll: 0.3891 - 2_recalll: 0.4795 - 3_recalll: 0.5132 - 4_recalll: 0.8749 - 0_precision: 0.7710 - 1_precision: 0.5122 - 2_precision: 0.5563 - 3_precision: 0.5862 - 4_precision: 0.8013 - val_loss: 0.6773 - val_all_acc: 0.7133 - val_0_recalll: 0.7994 - val_1_recalll: 0.4320 - val_2_recalll: 0.5777 - val_3_recalll: 0.5232 - val_4_recalll: 0.8647 - val_0_precision: 0.8343 - val_1_precision: 0.5489 - val_2_precision: 0.5207 - val_3_precision: 0.5543 - val_4_precision: 0.8256
# Epoch 56/150
# 100/100 [==============================] - 39s 392ms/step - loss: 0.6915 - all_acc: 0.7062 - 0_recalll: 0.8420 - 1_recalll: 0.4099 - 2_recalll: 0.4777 - 3_recalll: 0.5178 - 4_recalll: 0.8723 - 0_precision: 0.7618 - 1_precision: 0.5229 - 2_precision: 0.5629 - 3_precision: 0.5863 - 4_precision: 0.8042 - val_loss: 0.6804 - val_all_acc: 0.7148 - val_0_recalll: 0.8951 - val_1_recalll: 0.5105 - val_2_recalll: 0.4046 - val_3_recalll: 0.4035 - val_4_recalll: 0.9246 - val_0_precision: 0.7483 - val_1_precision: 0.4840 - val_2_precision: 0.5766 - val_3_precision: 0.6095 - val_4_precision: 0.7916
# Epoch 57/150
# 100/100 [==============================] - 41s 409ms/step - loss: 0.6986 - all_acc: 0.7019 - 0_recalll: 0.8448 - 1_recalll: 0.3811 - 2_recalll: 0.4705 - 3_recalll: 0.5137 - 4_recalll: 0.8754 - 0_precision: 0.7559 - 1_precision: 0.5057 - 2_precision: 0.5414 - 3_precision: 0.5832 - 4_precision: 0.8023 - val_loss: 0.6815 - val_all_acc: 0.7090 - val_0_recalll: 0.7460 - val_1_recalll: 0.6032 - val_2_recalll: 0.5074 - val_3_recalll: 0.4101 - val_4_recalll: 0.9110 - val_0_precision: 0.8379 - val_1_precision: 0.4751 - val_2_precision: 0.5507 - val_3_precision: 0.5915 - val_4_precision: 0.7955
# Epoch 58/150
# 100/100 [==============================] - 41s 413ms/step - loss: 0.6758 - all_acc: 0.7126 - 0_recalll: 0.8606 - 1_recalll: 0.3767 - 2_recalll: 0.4634 - 3_recalll: 0.5251 - 4_recalll: 0.8824 - 0_precision: 0.7680 - 1_precision: 0.5113 - 2_precision: 0.5580 - 3_precision: 0.5957 - 4_precision: 0.8091 - val_loss: 0.6676 - val_all_acc: 0.7186 - val_0_recalll: 0.8932 - val_1_recalll: 0.3802 - val_2_recalll: 0.4272 - val_3_recalll: 0.5644 - val_4_recalll: 0.8767 - val_0_precision: 0.7505 - val_1_precision: 0.5536 - val_2_precision: 0.5970 - val_3_precision: 0.5574 - val_4_precision: 0.8253
# Epoch 59/150
# 100/100 [==============================] - 39s 391ms/step - loss: 0.6775 - all_acc: 0.7108 - 0_recalll: 0.8597 - 1_recalll: 0.3852 - 2_recalll: 0.4823 - 3_recalll: 0.5197 - 4_recalll: 0.8756 - 0_precision: 0.7734 - 1_precision: 0.5048 - 2_precision: 0.5506 - 3_precision: 0.5941 - 4_precision: 0.8046 - val_loss: 0.6762 - val_all_acc: 0.7170 - val_0_recalll: 0.8140 - val_1_recalll: 0.6356 - val_2_recalll: 0.3638 - val_3_recalll: 0.5611 - val_4_recalll: 0.8679 - val_0_precision: 0.8155 - val_1_precision: 0.4537 - val_2_precision: 0.6213 - val_3_precision: 0.5718 - val_4_precision: 0.8342
# Epoch 60/150
# 100/100 [==============================] - 40s 400ms/step - loss: 0.6898 - all_acc: 0.7089 - 0_recalll: 0.8498 - 1_recalll: 0.4334 - 2_recalll: 0.4554 - 3_recalll: 0.5213 - 4_recalll: 0.8774 - 0_precision: 0.7770 - 1_precision: 0.5167 - 2_precision: 0.5545 - 3_precision: 0.5830 - 4_precision: 0.8077 - val_loss: 0.6629 - val_all_acc: 0.7188 - val_0_recalll: 0.8474 - val_1_recalll: 0.4805 - val_2_recalll: 0.4463 - val_3_recalll: 0.5620 - val_4_recalll: 0.8697 - val_0_precision: 0.7920 - val_1_precision: 0.5250 - val_2_precision: 0.5904 - val_3_precision: 0.5551 - val_4_precision: 0.8288
# Epoch 61/150
# 100/100 [==============================] - 41s 414ms/step - loss: 0.6823 - all_acc: 0.7108 - 0_recalll: 0.8682 - 1_recalll: 0.3804 - 2_recalll: 0.4619 - 3_recalll: 0.5165 - 4_recalll: 0.8759 - 0_precision: 0.7757 - 1_precision: 0.4961 - 2_precision: 0.5500 - 3_precision: 0.5758 - 4_precision: 0.8102 - val_loss: 0.6611 - val_all_acc: 0.7205 - val_0_recalll: 0.8737 - val_1_recalll: 0.3587 - val_2_recalll: 0.5451 - val_3_recalll: 0.4704 - val_4_recalll: 0.9047 - val_0_precision: 0.7707 - val_1_precision: 0.5677 - val_2_precision: 0.5503 - val_3_precision: 0.5933 - val_4_precision: 0.8050
# Epoch 62/150
# 100/100 [==============================] - 40s 400ms/step - loss: 0.6745 - all_acc: 0.7156 - 0_recalll: 0.8762 - 1_recalll: 0.4009 - 2_recalll: 0.4598 - 3_recalll: 0.5031 - 4_recalll: 0.8794 - 0_precision: 0.7893 - 1_precision: 0.5158 - 2_precision: 0.5553 - 3_precision: 0.5670 - 4_precision: 0.8090 - val_loss: 0.6753 - val_all_acc: 0.7092 - val_0_recalll: 0.8761 - val_1_recalll: 0.3732 - val_2_recalll: 0.5253 - val_3_recalll: 0.6072 - val_4_recalll: 0.8179 - val_0_precision: 0.7816 - val_1_precision: 0.5753 - val_2_precision: 0.5506 - val_3_precision: 0.5261 - val_4_precision: 0.8480
# Epoch 63/150
# 100/100 [==============================] - 39s 391ms/step - loss: 0.6725 - all_acc: 0.7180 - 0_recalll: 0.8786 - 1_recalll: 0.3729 - 2_recalll: 0.4702 - 3_recalll: 0.4997 - 4_recalll: 0.8824 - 0_precision: 0.7941 - 1_precision: 0.5141 - 2_precision: 0.5492 - 3_precision: 0.5810 - 4_precision: 0.8083 - val_loss: 0.6632 - val_all_acc: 0.7201 - val_0_recalll: 0.8817 - val_1_recalll: 0.3521 - val_2_recalll: 0.5188 - val_3_recalll: 0.5495 - val_4_recalll: 0.8749 - val_0_precision: 0.7624 - val_1_precision: 0.5583 - val_2_precision: 0.5660 - val_3_precision: 0.5731 - val_4_precision: 0.8256
# Epoch 64/150
# 100/100 [==============================] - 42s 417ms/step - loss: 0.6686 - all_acc: 0.7189 - 0_recalll: 0.8852 - 1_recalll: 0.3673 - 2_recalll: 0.4771 - 3_recalll: 0.4959 - 4_recalll: 0.8829 - 0_precision: 0.7923 - 1_precision: 0.5318 - 2_precision: 0.5472 - 3_precision: 0.5771 - 4_precision: 0.8069 - val_loss: 0.6662 - val_all_acc: 0.7203 - val_0_recalll: 0.8459 - val_1_recalll: 0.4917 - val_2_recalll: 0.4801 - val_3_recalll: 0.6026 - val_4_recalll: 0.8448 - val_0_precision: 0.7842 - val_1_precision: 0.5257 - val_2_precision: 0.6070 - val_3_precision: 0.5533 - val_4_precision: 0.8466
# Epoch 65/150
# 100/100 [==============================] - 41s 408ms/step - loss: 0.6665 - all_acc: 0.7163 - 0_recalll: 0.8729 - 1_recalll: 0.3798 - 2_recalll: 0.4648 - 3_recalll: 0.5144 - 4_recalll: 0.8752 - 0_precision: 0.7789 - 1_precision: 0.5244 - 2_precision: 0.5571 - 3_precision: 0.5785 - 4_precision: 0.8092 - val_loss: 0.6615 - val_all_acc: 0.7230 - val_0_recalll: 0.8416 - val_1_recalll: 0.5182 - val_2_recalll: 0.3955 - val_3_recalll: 0.5637 - val_4_recalll: 0.8869 - val_0_precision: 0.7907 - val_1_precision: 0.5198 - val_2_precision: 0.6369 - val_3_precision: 0.5671 - val_4_precision: 0.8226
# Epoch 66/150
# 100/100 [==============================] - 39s 392ms/step - loss: 0.6811 - all_acc: 0.7128 - 0_recalll: 0.8605 - 1_recalll: 0.3947 - 2_recalll: 0.4604 - 3_recalll: 0.5110 - 4_recalll: 0.8837 - 0_precision: 0.7699 - 1_precision: 0.5070 - 2_precision: 0.5459 - 3_precision: 0.5778 - 4_precision: 0.8129 - val_loss: 0.6578 - val_all_acc: 0.7174 - val_0_recalll: 0.8535 - val_1_recalll: 0.4651 - val_2_recalll: 0.4266 - val_3_recalll: 0.5722 - val_4_recalll: 0.8679 - val_0_precision: 0.7841 - val_1_precision: 0.5324 - val_2_precision: 0.5931 - val_3_precision: 0.5468 - val_4_precision: 0.8304
# Epoch 67/150
# 100/100 [==============================] - 41s 408ms/step - loss: 0.6828 - all_acc: 0.7096 - 0_recalll: 0.8606 - 1_recalll: 0.3879 - 2_recalll: 0.4587 - 3_recalll: 0.5295 - 4_recalll: 0.8748 - 0_precision: 0.7641 - 1_precision: 0.5115 - 2_precision: 0.5533 - 3_precision: 0.5882 - 4_precision: 0.8086 - val_loss: 0.6580 - val_all_acc: 0.7168 - val_0_recalll: 0.8614 - val_1_recalll: 0.3445 - val_2_recalll: 0.5200 - val_3_recalll: 0.5311 - val_4_recalll: 0.8799 - val_0_precision: 0.7769 - val_1_precision: 0.5532 - val_2_precision: 0.5592 - val_3_precision: 0.5624 - val_4_precision: 0.8188
# Epoch 68/150
# 100/100 [==============================] - 41s 411ms/step - loss: 0.6766 - all_acc: 0.7102 - 0_recalll: 0.8553 - 1_recalll: 0.4124 - 2_recalll: 0.4651 - 3_recalll: 0.5153 - 4_recalll: 0.8772 - 0_precision: 0.7724 - 1_precision: 0.5188 - 2_precision: 0.5627 - 3_precision: 0.5796 - 4_precision: 0.8049 - val_loss: 0.6558 - val_all_acc: 0.7240 - val_0_recalll: 0.8550 - val_1_recalll: 0.3686 - val_2_recalll: 0.5456 - val_3_recalll: 0.4806 - val_4_recalll: 0.9115 - val_0_precision: 0.7832 - val_1_precision: 0.5620 - val_2_precision: 0.5704 - val_3_precision: 0.5935 - val_4_precision: 0.8048
# Epoch 69/150
# 100/100 [==============================] - 40s 403ms/step - loss: 0.6884 - all_acc: 0.7075 - 0_recalll: 0.8510 - 1_recalll: 0.4094 - 2_recalll: 0.4779 - 3_recalll: 0.5127 - 4_recalll: 0.8761 - 0_precision: 0.7670 - 1_precision: 0.5226 - 2_precision: 0.5610 - 3_precision: 0.5844 - 4_precision: 0.8029 - val_loss: 0.6655 - val_all_acc: 0.7188 - val_0_recalll: 0.8870 - val_1_recalll: 0.3859 - val_2_recalll: 0.5868 - val_3_recalll: 0.3469 - val_4_recalll: 0.9396 - val_0_precision: 0.7805 - val_1_precision: 0.5928 - val_2_precision: 0.5431 - val_3_precision: 0.6266 - val_4_precision: 0.7767
# Epoch 70/150
# 100/100 [==============================] - 40s 399ms/step - loss: 0.6945 - all_acc: 0.7035 - 0_recalll: 0.8528 - 1_recalll: 0.3751 - 2_recalll: 0.4732 - 3_recalll: 0.5096 - 4_recalll: 0.8730 - 0_precision: 0.7562 - 1_precision: 0.5039 - 2_precision: 0.5557 - 3_precision: 0.5801 - 4_precision: 0.8023 - val_loss: 0.6539 - val_all_acc: 0.7252 - val_0_recalll: 0.8617 - val_1_recalll: 0.3687 - val_2_recalll: 0.5347 - val_3_recalll: 0.5199 - val_4_recalll: 0.8973 - val_0_precision: 0.7853 - val_1_precision: 0.5742 - val_2_precision: 0.5658 - val_3_precision: 0.5879 - val_4_precision: 0.8152
# Epoch 71/150
# 100/100 [==============================] - 41s 415ms/step - loss: 0.6741 - all_acc: 0.7157 - 0_recalll: 0.8640 - 1_recalll: 0.3982 - 2_recalll: 0.4646 - 3_recalll: 0.5282 - 4_recalll: 0.8803 - 0_precision: 0.7842 - 1_precision: 0.5104 - 2_precision: 0.5588 - 3_precision: 0.5886 - 4_precision: 0.8095 - val_loss: 0.6730 - val_all_acc: 0.7160 - val_0_recalll: 0.8252 - val_1_recalll: 0.4495 - val_2_recalll: 0.4588 - val_3_recalll: 0.4266 - val_4_recalll: 0.9361 - val_0_precision: 0.8049 - val_1_precision: 0.5596 - val_2_precision: 0.5978 - val_3_precision: 0.5804 - val_4_precision: 0.7721
# Epoch 72/150
# 100/100 [==============================] - 41s 407ms/step - loss: 0.6712 - all_acc: 0.7209 - 0_recalll: 0.8863 - 1_recalll: 0.3858 - 2_recalll: 0.4541 - 3_recalll: 0.5188 - 4_recalll: 0.8823 - 0_precision: 0.7937 - 1_precision: 0.5279 - 2_precision: 0.5381 - 3_precision: 0.5890 - 4_precision: 0.8091 - val_loss: 0.6617 - val_all_acc: 0.7211 - val_0_recalll: 0.8253 - val_1_recalll: 0.4954 - val_2_recalll: 0.4011 - val_3_recalll: 0.5643 - val_4_recalll: 0.8913 - val_0_precision: 0.8068 - val_1_precision: 0.5366 - val_2_precision: 0.6270 - val_3_precision: 0.5517 - val_4_precision: 0.8196
# Epoch 73/150
# 100/100 [==============================] - 39s 390ms/step - loss: 0.6627 - all_acc: 0.7222 - 0_recalll: 0.8750 - 1_recalll: 0.4020 - 2_recalll: 0.4645 - 3_recalll: 0.5180 - 4_recalll: 0.8847 - 0_precision: 0.7835 - 1_precision: 0.5221 - 2_precision: 0.5618 - 3_precision: 0.5951 - 4_precision: 0.8098 - val_loss: 0.6620 - val_all_acc: 0.7184 - val_0_recalll: 0.9026 - val_1_recalll: 0.4358 - val_2_recalll: 0.4169 - val_3_recalll: 0.4967 - val_4_recalll: 0.8992 - val_0_precision: 0.7254 - val_1_precision: 0.5012 - val_2_precision: 0.5865 - val_3_precision: 0.5923 - val_4_precision: 0.8188
# Epoch 74/150
# 100/100 [==============================] - 41s 415ms/step - loss: 0.6643 - all_acc: 0.7187 - 0_recalll: 0.8684 - 1_recalll: 0.4043 - 2_recalll: 0.4673 - 3_recalll: 0.5177 - 4_recalll: 0.8838 - 0_precision: 0.7822 - 1_precision: 0.5297 - 2_precision: 0.5516 - 3_precision: 0.5917 - 4_precision: 0.8090 - val_loss: 0.6687 - val_all_acc: 0.7139 - val_0_recalll: 0.8821 - val_1_recalll: 0.3653 - val_2_recalll: 0.5724 - val_3_recalll: 0.3422 - val_4_recalll: 0.9404 - val_0_precision: 0.7527 - val_1_precision: 0.5658 - val_2_precision: 0.5473 - val_3_precision: 0.6327 - val_4_precision: 0.7744
# Epoch 75/150
# 100/100 [==============================] - 41s 410ms/step - loss: 0.6769 - all_acc: 0.7083 - 0_recalll: 0.8520 - 1_recalll: 0.4073 - 2_recalll: 0.4676 - 3_recalll: 0.4999 - 4_recalll: 0.8794 - 0_precision: 0.7653 - 1_precision: 0.5212 - 2_precision: 0.5437 - 3_precision: 0.5753 - 4_precision: 0.8084 - val_loss: 0.6709 - val_all_acc: 0.7166 - val_0_recalll: 0.8930 - val_1_recalll: 0.3754 - val_2_recalll: 0.3840 - val_3_recalll: 0.4832 - val_4_recalll: 0.9240 - val_0_precision: 0.7472 - val_1_precision: 0.5546 - val_2_precision: 0.6105 - val_3_precision: 0.5659 - val_4_precision: 0.7937
# Epoch 76/150
# 100/100 [==============================] - 40s 399ms/step - loss: 0.6696 - all_acc: 0.7179 - 0_recalll: 0.8678 - 1_recalll: 0.3850 - 2_recalll: 0.4722 - 3_recalll: 0.5247 - 4_recalll: 0.8822 - 0_precision: 0.7716 - 1_precision: 0.5199 - 2_precision: 0.5505 - 3_precision: 0.6006 - 4_precision: 0.8072 - val_loss: 0.6738 - val_all_acc: 0.7139 - val_0_recalll: 0.8815 - val_1_recalll: 0.4407 - val_2_recalll: 0.4952 - val_3_recalll: 0.6290 - val_4_recalll: 0.8119 - val_0_precision: 0.7707 - val_1_precision: 0.5291 - val_2_precision: 0.5674 - val_3_precision: 0.5397 - val_4_precision: 0.8636
# Epoch 77/150
# 100/100 [==============================] - 40s 398ms/step - loss: 0.6731 - all_acc: 0.7127 - 0_recalll: 0.8442 - 1_recalll: 0.4356 - 2_recalll: 0.4763 - 3_recalll: 0.5285 - 4_recalll: 0.8769 - 0_precision: 0.7641 - 1_precision: 0.5353 - 2_precision: 0.5764 - 3_precision: 0.5893 - 4_precision: 0.8049 - val_loss: 0.6667 - val_all_acc: 0.7195 - val_0_recalll: 0.8508 - val_1_recalll: 0.3949 - val_2_recalll: 0.5808 - val_3_recalll: 0.5996 - val_4_recalll: 0.8336 - val_0_precision: 0.8016 - val_1_precision: 0.5670 - val_2_precision: 0.5367 - val_3_precision: 0.5575 - val_4_precision: 0.8522
# Epoch 78/150
# 100/100 [==============================] - 41s 410ms/step - loss: 0.6790 - all_acc: 0.7123 - 0_recalll: 0.8574 - 1_recalll: 0.3783 - 2_recalll: 0.4988 - 3_recalll: 0.5217 - 4_recalll: 0.8778 - 0_precision: 0.7599 - 1_precision: 0.5178 - 2_precision: 0.5781 - 3_precision: 0.5938 - 4_precision: 0.8007 - val_loss: 0.6605 - val_all_acc: 0.7182 - val_0_recalll: 0.8965 - val_1_recalll: 0.4190 - val_2_recalll: 0.4751 - val_3_recalll: 0.4713 - val_4_recalll: 0.9008 - val_0_precision: 0.7488 - val_1_precision: 0.5057 - val_2_precision: 0.5798 - val_3_precision: 0.5895 - val_4_precision: 0.8098
# Epoch 79/150
# 100/100 [==============================] - 41s 410ms/step - loss: 0.6738 - all_acc: 0.7105 - 0_recalll: 0.8528 - 1_recalll: 0.4041 - 2_recalll: 0.4701 - 3_recalll: 0.5300 - 4_recalll: 0.8747 - 0_precision: 0.7671 - 1_precision: 0.5116 - 2_precision: 0.5558 - 3_precision: 0.5912 - 4_precision: 0.8054 - val_loss: 0.6686 - val_all_acc: 0.7113 - val_0_recalll: 0.7349 - val_1_recalll: 0.5379 - val_2_recalll: 0.5218 - val_3_recalll: 0.5001 - val_4_recalll: 0.8858 - val_0_precision: 0.8425 - val_1_precision: 0.4596 - val_2_precision: 0.5485 - val_3_precision: 0.5776 - val_4_precision: 0.8189
# Epoch 80/150
# ...
# Epoch 125/150
# 100/100 [==============================] - 41s 411ms/step - loss: 0.6449 - all_acc: 0.7281 - 0_recalll: 0.8784 - 1_recalll: 0.4121 - 2_recalll: 0.4719 - 3_recalll: 0.5306 - 4_recalll: 0.8862 - 0_precision: 0.7874 - 1_precision: 0.5349 - 2_precision: 0.5605 - 3_precision: 0.5960 - 4_precision: 0.8174 - val_loss: 0.6438 - val_all_acc: 0.7244 - val_0_recalll: 0.8817 - val_1_recalll: 0.4837 - val_2_recalll: 0.4010 - val_3_recalll: 0.4863 - val_4_recalll: 0.9198 - val_0_precision: 0.7686 - val_1_precision: 0.5314 - val_2_precision: 0.6464 - val_3_precision: 0.5789 - val_4_precision: 0.8018
# Epoch 126/150
# 100/100 [==============================] - 40s 403ms/step - loss: 0.6480 - all_acc: 0.7259 - 0_recalll: 0.8697 - 1_recalll: 0.4295 - 2_recalll: 0.4633 - 3_recalll: 0.5244 - 4_recalll: 0.8890 - 0_precision: 0.7837 - 1_precision: 0.5360 - 2_precision: 0.5709 - 3_precision: 0.6009 - 4_precision: 0.8126 - val_loss: 0.6392 - val_all_acc: 0.7332 - val_0_recalll: 0.8319 - val_1_recalll: 0.5352 - val_2_recalll: 0.5299 - val_3_recalll: 0.5468 - val_4_recalll: 0.8833 - val_0_precision: 0.8122 - val_1_precision: 0.5605 - val_2_precision: 0.6043 - val_3_precision: 0.5878 - val_4_precision: 0.8305
# Epoch 127/150
# 100/100 [==============================] - 41s 407ms/step - loss: 0.6471 - all_acc: 0.7219 - 0_recalll: 0.8592 - 1_recalll: 0.4004 - 2_recalll: 0.4876 - 3_recalll: 0.5318 - 4_recalll: 0.8871 - 0_precision: 0.7747 - 1_precision: 0.5082 - 2_precision: 0.5689 - 3_precision: 0.6006 - 4_precision: 0.8146 - val_loss: 0.6422 - val_all_acc: 0.7324 - val_0_recalll: 0.8499 - val_1_recalll: 0.4252 - val_2_recalll: 0.5117 - val_3_recalll: 0.5917 - val_4_recalll: 0.8793 - val_0_precision: 0.8140 - val_1_precision: 0.5769 - val_2_precision: 0.5911 - val_3_precision: 0.5743 - val_4_precision: 0.8371
# Epoch 128/150
# 100/100 [==============================] - 41s 411ms/step - loss: 0.6512 - all_acc: 0.7218 - 0_recalll: 0.8644 - 1_recalll: 0.4165 - 2_recalll: 0.4844 - 3_recalll: 0.5114 - 4_recalll: 0.8864 - 0_precision: 0.7853 - 1_precision: 0.5268 - 2_precision: 0.5664 - 3_precision: 0.5834 - 4_precision: 0.8112 - val_loss: 0.6411 - val_all_acc: 0.7281 - val_0_recalll: 0.8626 - val_1_recalll: 0.5344 - val_2_recalll: 0.3938 - val_3_recalll: 0.5793 - val_4_recalll: 0.8825 - val_0_precision: 0.8031 - val_1_precision: 0.5240 - val_2_precision: 0.6311 - val_3_precision: 0.5668 - val_4_precision: 0.8351
# Epoch 129/150
# 100/100 [==============================] - 40s 397ms/step - loss: 0.6545 - all_acc: 0.7195 - 0_recalll: 0.8695 - 1_recalll: 0.4087 - 2_recalll: 0.4947 - 3_recalll: 0.5166 - 4_recalll: 0.8839 - 0_precision: 0.7768 - 1_precision: 0.5193 - 2_precision: 0.5735 - 3_precision: 0.5968 - 4_precision: 0.8065 - val_loss: 0.6426 - val_all_acc: 0.7275 - val_0_recalll: 0.8387 - val_1_recalll: 0.4140 - val_2_recalll: 0.5535 - val_3_recalll: 0.5935 - val_4_recalll: 0.8627 - val_0_precision: 0.8171 - val_1_precision: 0.5620 - val_2_precision: 0.5754 - val_3_precision: 0.5701 - val_4_precision: 0.8405
# Epoch 130/150
# 100/100 [==============================] - 41s 409ms/step - loss: 0.6533 - all_acc: 0.7201 - 0_recalll: 0.8633 - 1_recalll: 0.4119 - 2_recalll: 0.5034 - 3_recalll: 0.5393 - 4_recalll: 0.8758 - 0_precision: 0.7820 - 1_precision: 0.5241 - 2_precision: 0.5799 - 3_precision: 0.5999 - 4_precision: 0.8091 - val_loss: 0.6437 - val_all_acc: 0.7277 - val_0_recalll: 0.8496 - val_1_recalll: 0.4588 - val_2_recalll: 0.4737 - val_3_recalll: 0.5924 - val_4_recalll: 0.8720 - val_0_precision: 0.8084 - val_1_precision: 0.5601 - val_2_precision: 0.5981 - val_3_precision: 0.5602 - val_4_precision: 0.8375
# Epoch 131/150
# 100/100 [==============================] - 41s 405ms/step - loss: 0.6573 - all_acc: 0.7217 - 0_recalll: 0.8614 - 1_recalll: 0.4233 - 2_recalll: 0.4952 - 3_recalll: 0.5375 - 4_recalll: 0.8812 - 0_precision: 0.7812 - 1_precision: 0.5258 - 2_precision: 0.5829 - 3_precision: 0.6020 - 4_precision: 0.8092 - val_loss: 0.6366 - val_all_acc: 0.7350 - val_0_recalll: 0.8802 - val_1_recalll: 0.4407 - val_2_recalll: 0.5018 - val_3_recalll: 0.5292 - val_4_recalll: 0.9057 - val_0_precision: 0.7739 - val_1_precision: 0.5556 - val_2_precision: 0.6184 - val_3_precision: 0.6056 - val_4_precision: 0.8221
# Epoch 132/150
# 100/100 [==============================] - 41s 406ms/step - loss: 0.6576 - all_acc: 0.7196 - 0_recalll: 0.8608 - 1_recalll: 0.4520 - 2_recalll: 0.4891 - 3_recalll: 0.5174 - 4_recalll: 0.8864 - 0_precision: 0.7780 - 1_precision: 0.5527 - 2_precision: 0.5700 - 3_precision: 0.5972 - 4_precision: 0.8069 - val_loss: 0.6400 - val_all_acc: 0.7316 - val_0_recalll: 0.8157 - val_1_recalll: 0.5570 - val_2_recalll: 0.5045 - val_3_recalll: 0.5570 - val_4_recalll: 0.8821 - val_0_precision: 0.8284 - val_1_precision: 0.5245 - val_2_precision: 0.6161 - val_3_precision: 0.5898 - val_4_precision: 0.8307
# Epoch 133/150
# 100/100 [==============================] - 40s 400ms/step - loss: 0.6533 - all_acc: 0.7196 - 0_recalll: 0.8624 - 1_recalll: 0.4247 - 2_recalll: 0.4848 - 3_recalll: 0.5230 - 4_recalll: 0.8855 - 0_precision: 0.7720 - 1_precision: 0.5251 - 2_precision: 0.5723 - 3_precision: 0.5988 - 4_precision: 0.8108 - val_loss: 0.6424 - val_all_acc: 0.7303 - val_0_recalll: 0.8666 - val_1_recalll: 0.4261 - val_2_recalll: 0.6083 - val_3_recalll: 0.4288 - val_4_recalll: 0.9226 - val_0_precision: 0.7993 - val_1_precision: 0.5694 - val_2_precision: 0.5449 - val_3_precision: 0.6380 - val_4_precision: 0.8062
# Epoch 134/150
# 100/100 [==============================] - 40s 400ms/step - loss: 0.6492 - all_acc: 0.7257 - 0_recalll: 0.8713 - 1_recalll: 0.4413 - 2_recalll: 0.4962 - 3_recalll: 0.5375 - 4_recalll: 0.8839 - 0_precision: 0.7900 - 1_precision: 0.5316 - 2_precision: 0.5829 - 3_precision: 0.6107 - 4_precision: 0.8100 - val_loss: 0.6359 - val_all_acc: 0.7314 - val_0_recalll: 0.8655 - val_1_recalll: 0.3886 - val_2_recalll: 0.5268 - val_3_recalll: 0.5933 - val_4_recalll: 0.8745 - val_0_precision: 0.7860 - val_1_precision: 0.5473 - val_2_precision: 0.5874 - val_3_precision: 0.5833 - val_4_precision: 0.8427
# Epoch 135/150
# 100/100 [==============================] - 42s 415ms/step - loss: 0.6614 - all_acc: 0.7179 - 0_recalll: 0.8637 - 1_recalll: 0.4009 - 2_recalll: 0.4854 - 3_recalll: 0.5369 - 4_recalll: 0.8796 - 0_precision: 0.7784 - 1_precision: 0.5087 - 2_precision: 0.5706 - 3_precision: 0.6011 - 4_precision: 0.8094 - val_loss: 0.6390 - val_all_acc: 0.7338 - val_0_recalll: 0.8466 - val_1_recalll: 0.5626 - val_2_recalll: 0.4677 - val_3_recalll: 0.5266 - val_4_recalll: 0.9004 - val_0_precision: 0.8102 - val_1_precision: 0.5142 - val_2_precision: 0.6083 - val_3_precision: 0.6091 - val_4_precision: 0.8269
# Epoch 136/150
# 100/100 [==============================] - 39s 389ms/step - loss: 0.6541 - all_acc: 0.7216 - 0_recalll: 0.8607 - 1_recalll: 0.4085 - 2_recalll: 0.4971 - 3_recalll: 0.5401 - 4_recalll: 0.8820 - 0_precision: 0.7786 - 1_precision: 0.5131 - 2_precision: 0.5643 - 3_precision: 0.6105 - 4_precision: 0.8129 - val_loss: 0.6443 - val_all_acc: 0.7281 - val_0_recalll: 0.8609 - val_1_recalll: 0.3786 - val_2_recalll: 0.4949 - val_3_recalll: 0.6353 - val_4_recalll: 0.8591 - val_0_precision: 0.7953 - val_1_precision: 0.5552 - val_2_precision: 0.5677 - val_3_precision: 0.5703 - val_4_precision: 0.8515
# Epoch 137/150
# 100/100 [==============================] - 41s 407ms/step - loss: 0.6578 - all_acc: 0.7202 - 0_recalll: 0.8622 - 1_recalll: 0.4368 - 2_recalll: 0.4842 - 3_recalll: 0.5290 - 4_recalll: 0.8832 - 0_precision: 0.7862 - 1_precision: 0.5310 - 2_precision: 0.5605 - 3_precision: 0.5998 - 4_precision: 0.8108 - val_loss: 0.6464 - val_all_acc: 0.7289 - val_0_recalll: 0.9071 - val_1_recalll: 0.4740 - val_2_recalll: 0.4542 - val_3_recalll: 0.5405 - val_4_recalll: 0.8828 - val_0_precision: 0.7384 - val_1_precision: 0.5022 - val_2_precision: 0.6132 - val_3_precision: 0.6059 - val_4_precision: 0.8371
# Epoch 138/150
# 100/100 [==============================] - 41s 411ms/step - loss: 0.6554 - all_acc: 0.7234 - 0_recalll: 0.8659 - 1_recalll: 0.3952 - 2_recalll: 0.5090 - 3_recalll: 0.5361 - 4_recalll: 0.8870 - 0_precision: 0.7736 - 1_precision: 0.5178 - 2_precision: 0.5825 - 3_precision: 0.6101 - 4_precision: 0.8146 - val_loss: 0.6464 - val_all_acc: 0.7271 - val_0_recalll: 0.8755 - val_1_recalll: 0.4286 - val_2_recalll: 0.4815 - val_3_recalll: 0.4276 - val_4_recalll: 0.9437 - val_0_precision: 0.7847 - val_1_precision: 0.5475 - val_2_precision: 0.6179 - val_3_precision: 0.6108 - val_4_precision: 0.7844
# Epoch 139/150
# 100/100 [==============================] - 40s 395ms/step - loss: 0.6577 - all_acc: 0.7189 - 0_recalll: 0.8569 - 1_recalll: 0.4258 - 2_recalll: 0.4934 - 3_recalll: 0.5273 - 4_recalll: 0.8833 - 0_precision: 0.7843 - 1_precision: 0.5146 - 2_precision: 0.5728 - 3_precision: 0.5999 - 4_precision: 0.8083 - val_loss: 0.6360 - val_all_acc: 0.7326 - val_0_recalll: 0.8904 - val_1_recalll: 0.4104 - val_2_recalll: 0.5204 - val_3_recalll: 0.5661 - val_4_recalll: 0.8803 - val_0_precision: 0.7568 - val_1_precision: 0.5724 - val_2_precision: 0.6082 - val_3_precision: 0.5957 - val_4_precision: 0.8346
# Epoch 140/150
# 100/100 [==============================] - 40s 403ms/step - loss: 0.6572 - all_acc: 0.7230 - 0_recalll: 0.8625 - 1_recalll: 0.4260 - 2_recalll: 0.5009 - 3_recalll: 0.5124 - 4_recalll: 0.8858 - 0_precision: 0.7729 - 1_precision: 0.5500 - 2_precision: 0.5821 - 3_precision: 0.5903 - 4_precision: 0.8099 - val_loss: 0.6332 - val_all_acc: 0.7332 - val_0_recalll: 0.8535 - val_1_recalll: 0.4723 - val_2_recalll: 0.5085 - val_3_recalll: 0.5204 - val_4_recalll: 0.9052 - val_0_precision: 0.7973 - val_1_precision: 0.5527 - val_2_precision: 0.5831 - val_3_precision: 0.6056 - val_4_precision: 0.8233
# Epoch 141/150
# 100/100 [==============================] - 40s 404ms/step - loss: 0.6455 - all_acc: 0.7248 - 0_recalll: 0.8699 - 1_recalll: 0.4172 - 2_recalll: 0.4915 - 3_recalll: 0.5158 - 4_recalll: 0.8912 - 0_precision: 0.7806 - 1_precision: 0.5298 - 2_precision: 0.5613 - 3_precision: 0.6018 - 4_precision: 0.8135 - val_loss: 0.6392 - val_all_acc: 0.7318 - val_0_recalll: 0.8865 - val_1_recalll: 0.3844 - val_2_recalll: 0.5578 - val_3_recalll: 0.5500 - val_4_recalll: 0.8817 - val_0_precision: 0.7586 - val_1_precision: 0.5563 - val_2_precision: 0.5777 - val_3_precision: 0.5998 - val_4_precision: 0.8389
# Epoch 142/150
# 100/100 [==============================] - 41s 405ms/step - loss: 0.6425 - all_acc: 0.7305 - 0_recalll: 0.8749 - 1_recalll: 0.4112 - 2_recalll: 0.4998 - 3_recalll: 0.5255 - 4_recalll: 0.8905 - 0_precision: 0.7936 - 1_precision: 0.5374 - 2_precision: 0.5763 - 3_precision: 0.6011 - 4_precision: 0.8154 - val_loss: 0.6402 - val_all_acc: 0.7354 - val_0_recalll: 0.9231 - val_1_recalll: 0.3559 - val_2_recalll: 0.5127 - val_3_recalll: 0.5714 - val_4_recalll: 0.8844 - val_0_precision: 0.7340 - val_1_precision: 0.6043 - val_2_precision: 0.6040 - val_3_precision: 0.6007 - val_4_precision: 0.8400
# Epoch 143/150
# 100/100 [==============================] - 39s 394ms/step - loss: 0.6333 - all_acc: 0.7366 - 0_recalll: 0.8861 - 1_recalll: 0.3854 - 2_recalll: 0.4956 - 3_recalll: 0.5265 - 4_recalll: 0.8946 - 0_precision: 0.7914 - 1_precision: 0.5298 - 2_precision: 0.5681 - 3_precision: 0.6080 - 4_precision: 0.8222 - val_loss: 0.6410 - val_all_acc: 0.7316 - val_0_recalll: 0.8855 - val_1_recalll: 0.4119 - val_2_recalll: 0.5505 - val_3_recalll: 0.5682 - val_4_recalll: 0.8705 - val_0_precision: 0.7696 - val_1_precision: 0.5818 - val_2_precision: 0.5668 - val_3_precision: 0.5891 - val_4_precision: 0.8459
# Epoch 144/150
# 100/100 [==============================] - 41s 407ms/step - loss: 0.6315 - all_acc: 0.7329 - 0_recalll: 0.8897 - 1_recalll: 0.3933 - 2_recalll: 0.4910 - 3_recalll: 0.5254 - 4_recalll: 0.8894 - 0_precision: 0.7918 - 1_precision: 0.5461 - 2_precision: 0.5670 - 3_precision: 0.6014 - 4_precision: 0.8179 - val_loss: 0.6405 - val_all_acc: 0.7264 - val_0_recalll: 0.8893 - val_1_recalll: 0.4551 - val_2_recalll: 0.3931 - val_3_recalll: 0.5540 - val_4_recalll: 0.8959 - val_0_precision: 0.7483 - val_1_precision: 0.5065 - val_2_precision: 0.6121 - val_3_precision: 0.5948 - val_4_precision: 0.8280
# Epoch 145/150
# 100/100 [==============================] - 41s 413ms/step - loss: 0.6388 - all_acc: 0.7299 - 0_recalll: 0.8816 - 1_recalll: 0.4213 - 2_recalll: 0.4594 - 3_recalll: 0.5287 - 4_recalll: 0.8874 - 0_precision: 0.7951 - 1_precision: 0.5512 - 2_precision: 0.5489 - 3_precision: 0.5939 - 4_precision: 0.8162 - val_loss: 0.6399 - val_all_acc: 0.7311 - val_0_recalll: 0.8284 - val_1_recalll: 0.4458 - val_2_recalll: 0.5070 - val_3_recalll: 0.5885 - val_4_recalll: 0.8806 - val_0_precision: 0.8130 - val_1_precision: 0.5601 - val_2_precision: 0.5669 - val_3_precision: 0.5847 - val_4_precision: 0.8387
# Epoch 146/150
# 100/100 [==============================] - 39s 385ms/step - loss: 0.6405 - all_acc: 0.7289 - 0_recalll: 0.8765 - 1_recalll: 0.4093 - 2_recalll: 0.4934 - 3_recalll: 0.5512 - 4_recalll: 0.8826 - 0_precision: 0.7882 - 1_precision: 0.5255 - 2_precision: 0.5650 - 3_precision: 0.6179 - 4_precision: 0.8158 - val_loss: 0.6364 - val_all_acc: 0.7332 - val_0_recalll: 0.8549 - val_1_recalll: 0.4541 - val_2_recalll: 0.4838 - val_3_recalll: 0.5707 - val_4_recalll: 0.8916 - val_0_precision: 0.7947 - val_1_precision: 0.5696 - val_2_precision: 0.5951 - val_3_precision: 0.5933 - val_4_precision: 0.8285
# Epoch 147/150
# 100/100 [==============================] - 41s 409ms/step - loss: 0.6550 - all_acc: 0.7196 - 0_recalll: 0.8613 - 1_recalll: 0.4504 - 2_recalll: 0.4696 - 3_recalll: 0.5337 - 4_recalll: 0.8795 - 0_precision: 0.7841 - 1_precision: 0.5390 - 2_precision: 0.5561 - 3_precision: 0.5933 - 4_precision: 0.8105 - val_loss: 0.6385 - val_all_acc: 0.7270 - val_0_recalll: 0.8743 - val_1_recalll: 0.4656 - val_2_recalll: 0.4239 - val_3_recalll: 0.5418 - val_4_recalll: 0.8976 - val_0_precision: 0.7784 - val_1_precision: 0.5396 - val_2_precision: 0.6235 - val_3_precision: 0.5743 - val_4_precision: 0.8201
# Epoch 148/150
# 100/100 [==============================] - 40s 404ms/step - loss: 0.6657 - all_acc: 0.7180 - 0_recalll: 0.8515 - 1_recalll: 0.4479 - 2_recalll: 0.4844 - 3_recalll: 0.5459 - 4_recalll: 0.8782 - 0_precision: 0.7636 - 1_precision: 0.5457 - 2_precision: 0.5809 - 3_precision: 0.5964 - 4_precision: 0.8115 - val_loss: 0.6348 - val_all_acc: 0.7281 - val_0_recalll: 0.8925 - val_1_recalll: 0.4078 - val_2_recalll: 0.4843 - val_3_recalll: 0.5348 - val_4_recalll: 0.8932 - val_0_precision: 0.7541 - val_1_precision: 0.5070 - val_2_precision: 0.6051 - val_3_precision: 0.6029 - val_4_precision: 0.8245
# Epoch 149/150
# 100/100 [==============================] - 40s 396ms/step - loss: 0.6573 - all_acc: 0.7209 - 0_recalll: 0.8633 - 1_recalll: 0.4358 - 2_recalll: 0.4842 - 3_recalll: 0.5476 - 4_recalll: 0.8781 - 0_precision: 0.7737 - 1_precision: 0.5340 - 2_precision: 0.5752 - 3_precision: 0.6107 - 4_precision: 0.8093 - val_loss: 0.6387 - val_all_acc: 0.7270 - val_0_recalll: 0.8993 - val_1_recalll: 0.4070 - val_2_recalll: 0.4023 - val_3_recalll: 0.5304 - val_4_recalll: 0.9116 - val_0_precision: 0.7402 - val_1_precision: 0.5316 - val_2_precision: 0.6152 - val_3_precision: 0.5879 - val_4_precision: 0.8193
# Epoch 150/150
# 100/100 [==============================] - 41s 407ms/step - loss: 0.6653 - all_acc: 0.7149 - 0_recalll: 0.8618 - 1_recalll: 0.4131 - 2_recalll: 0.4806 - 3_recalll: 0.5309 - 4_recalll: 0.8818 - 0_precision: 0.7739 - 1_precision: 0.5266 - 2_precision: 0.5527 - 3_precision: 0.5951 - 4_precision: 0.8092 - val_loss: 0.6386 - val_all_acc: 0.7299 - val_0_recalll: 0.8733 - val_1_recalll: 0.4973 - val_2_recalll: 0.4121 - val_3_recalll: 0.5817 - val_4_recalll: 0.8830 - val_0_precision: 0.7733 - val_1_precision: 0.5177 - val_2_precision: 0.6247 - val_3_precision: 0.5814 - val_4_precision: 0.8384

# %%
baby.save(os.path.join(MODELS_DIR, 'baby_conv_length.h5'))

# %%
results = baby.evaluate(dataset['test'], steps=5000)
# Out:
# 1599/5000 [========>.....................] - ETA: 13:29 - loss: 0.6410 - all_acc: 0.7269 - 0_recalll: 0.8819 - 1_recalll: 0.4618 - 2_recalll: 0.4366 - 3_recalll: 0.5786 - 4_recalll: 0.8731 - 0_precision: 0.7722 - 1_precision: 0.5208 - 2_precision: 0.6110 - 3_precision: 0.5929 - 4_precision: 0.8246

# %%
def get_f1_scores(results):
    m = {}
    m[1] = (results[2], results[7])
    m[2] = (results[3], results[8])
    m[3] = (results[4], results[9])
    m[4] = (results[5], results[10])
    m[5] = (results[6], results[11])
    f = {}
    total = 0
    for i in m:
        f[i] = 2 * np.product(m[i]) / np.sum(m[i])
        total+=f[i]
    f['macro'] = total/5
    return f, m

# %%
baby_embedding = baby.layers[1].get_weights()[0]
baby_dict = {key: baby_embedding[val] for key, val in keys_to_ix.items()}

# %%
dists, ix = neighbors(baby_dict['food'.encode()], baby_dict)

# %%
dists[dists.columns[ix]].T.head(10)
# Out:
#                       0
# b'cold'        0.152718
# b'coding'      0.154795
# b'irons'       0.195102
# b'one-inch'    0.205606
# b'velveeta'    0.209315
# b'frays'       0.213710
# b'swallowed'   0.213735
# b'connective'  0.219325
# b'polymer'     0.221030
# b'pepsico'     0.224535

# %%
dists_glove, ix_glove = neighbors((glove_lookup['cold'.encode()] +glove_lookup['food'.encode()])/2, glove_lookup)

# %%
dists_glove[dists_glove.columns[ix_glove]].T.head(10)
# Out:
#                       0
# b'food'        0.094483
# b'cold'        0.121795
# b'hot'         0.215604
# b'dry'         0.217672
# b'water'       0.220291
# b'fresh'       0.224757
# b'eating'      0.227453
# b'cooking'     0.229176
# b'especially'  0.241382
# b'keeping'     0.254835

# %% [raw]
# truth, predictions = [], []
# for x, y in dataset['test'].take(2500):
#     pred = baby(x)
#     truth.append(y['stars'].numpy())
#     predictions.append(tf.argmax(pred['stars'], axis=-1).numpy())
# predictions=np.array(predictions).flatten()
# truth = np.array(truth).flatten()
# print(classification_report(truth, predictions))

# %% [raw]
#               precision    recall  f1-score   support
#
#            0       0.75      0.90      0.81      3741
#            1       0.54      0.41      0.47      2192
#            2       0.58      0.50      0.53      2962
#            3       0.62      0.51      0.56      5724
#            4       0.81      0.89      0.85     10981
#
#     accuracy                           0.72     25600
#    macro avg       0.66      0.64      0.64     25600
# weighted avg       0.71      0.72      0.71     25600

# %% [raw]
# array([[3350,  295,   41,   22,   33],
#        [ 787,  897,  424,   56,   28],
#        [ 231,  411, 1469,  706,  145],
#        [  56,   46,  539, 2940, 2143],
#        [  69,   11,   60, 1039, 9802]])
